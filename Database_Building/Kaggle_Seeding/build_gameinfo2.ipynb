# %%
# import here
import pandas as pd
from sqlalchemy import create_engine
from references_dict import Team_Dictionary

# connect to database
kaggle_engine = create_engine('mysql+pymysql://root:@localhost:3306/kaggle')
kaggle_conn = kaggle_engine.connect()
nfldb_engine = create_engine('mysql+pymysql://root:@localhost:3306/nfl_db')
nfldb_conn = nfldb_engine.connect()
file = ("D:\\NFLDB\\game_info.csv")

# trim csv file to relevant stats for weeks 1-16, 2009-2018
df = pd.read_csv(file)

# drop playoff weeks
indexNames = df[ df['schedule_playoff'] == True ].index
df.drop(indexNames,inplace=True)

# drop stats older than 2009
indexNames = df[ df['schedule_season'] < 2009 ].index
df.drop(indexNames,inplace=True)

# %%
def get_home_favorite(row):
	home_team = row['team_home']
	home_abbrev = Team_Dictionary().kaggle_games_abbrev[home_team]
	if home_abbrev == row['team_favorite_id']:
		return 1
	else:
		return 0

def get_spread_result(row):
    score_fav = 0
    score_und = 0
    spread = row['spread_favorite']*-1
    if(row['home_favorite']==1):
        score_fav = row['score_home']
        score_und = row['score_away']
    else:
        score_fav = row['score_away']
        score_und = row['score_home']
    diff = score_fav-score_und
    if( diff > spread ):
        return 1
    elif( diff < spread ):
        return -1
    else:
        return 0

def get_OU_result(row):
    OU = float(row['over_under_line'])
    total = row['score_home']+row['score_away']
    if( total > OU ):
        return 1
    elif( total < OU ):
        return -1
    else:
        return 0

def get_index(row):
    date = row['schedule_date']
    comps = date.split('/')
    date = comps[2]+'-'+comps[0]+'-'+comps[1]
    return date+Team_Dictionary().kaggle_games_abbrev[row['team_home']]

# # generate metrics for dataset, set index
df['home_favorite'] = df.apply (lambda row: get_home_favorite(row), axis=1)
df['spread_result'] = df.apply(lambda row: get_spread_result(row),axis=1)
df['OU_result'] = df.apply(lambda row: get_OU_result(row),axis=1)
df['idx'] = df.apply(lambda row: get_index(row),axis=1)
df.set_index('idx',inplace=True)

def get_pbpindex(row):
    team_dict = dict([[v,k] for k,v in Team_Dictionary().kaggle_plays_abbrev.items()])
    team_name = team_dict[row['home_team']]
    team_name = Team_Dictionary().kaggle_games_abbrev[team_name]
    comps = row['game_date'].split('/')
    print(row,comps)
    date = comps[2]+'-'+comps[0]+'-'+comps[1]
    idx = date+team_name
    idx = row['game_date']+team_name
    return idx

# %%
# sql statement for getting gameids
sql = "select distinct(pbp.game_id) as game_id, pbp.home_team as home_team, pbp.game_date as game_date \
       from nfl_pbp pbp \
       order by pbp.game_id"
df_gameids = pd.read_sql_query(sql, kaggle_conn, index_col=None)
df_gameids['idx'] = df_gameids.apply(lambda row: get_pbpindex(row),axis=1)
df_gameids.head()
# Out:
# game_id      2009091000
# home_team           PIT
# game_date     9/10/2009
# Name: 0, dtype: object ['9', '10', '2009']
# game_id      2009091300
# home_team           ATL
# game_date     9/13/2009
# Name: 1, dtype: object ['9', '13', '2009']
# game_id      2009091301
# home_team           BAL
# game_date     9/13/2009
# Name: 2, dtype: object ['9', '13', '2009']
# game_id      2009091302
# home_team           CAR
# game_date     9/13/2009
# Name: 3, dtype: object ['9', '13', '2009']
# game_id      2009091303
# home_team           CIN
# game_date     9/13/2009
# Name: 4, dtype: object ['9', '13', '2009']
# game_id      2009091304
# home_team           CLE
# game_date     9/13/2009
# Name: 5, dtype: object ['9', '13', '2009']
# game_id      2009091305
# home_team           HOU
# game_date     9/13/2009
# Name: 6, dtype: object ['9', '13', '2009']
# game_id      2009091306
# home_team           IND
# game_date     9/13/2009
# Name: 7, dtype: object ['9', '13', '2009']
# game_id      2009091307
# home_team            NO
# game_date     9/13/2009
# Name: 8, dtype: object ['9', '13', '2009']
# game_id      2009091308
# home_team            TB
# game_date     9/13/2009
# Name: 9, dtype: object ['9', '13', '2009']
# game_id      2009091309
# home_team           ARI
# game_date     9/13/2009
# Name: 10, dtype: object ['9', '13', '2009']
# game_id      2009091310
# home_team           NYG
# game_date     9/13/2009
# Name: 11, dtype: object ['9', '13', '2009']
# game_id      2009091311
# home_team           SEA
# game_date     9/13/2009
# Name: 12, dtype: object ['9', '13', '2009']
# game_id      2009091312
# home_team            GB
# game_date     9/13/2009
# Name: 13, dtype: object ['9', '13', '2009']
# game_id      2009091400
# home_team            NE
# game_date     9/14/2009
# Name: 14, dtype: object ['9', '14', '2009']
# game_id      2009091401
# home_team           OAK
# game_date     9/14/2009
# Name: 15, dtype: object ['9', '14', '2009']
# game_id      2009092000
# home_team           ATL
# game_date     9/20/2009
# Name: 16, dtype: object ['9', '20', '2009']
# game_id      2009092001
# home_team           DET
# game_date     9/20/2009
# Name: 17, dtype: object ['9', '20', '2009']
# game_id      2009092002
# home_team            GB
# game_date     9/20/2009
# Name: 18, dtype: object ['9', '20', '2009']
# game_id      2009092003
# home_team           JAX
# game_date     9/20/2009
# Name: 19, dtype: object ['9', '20', '2009']
# game_id      2009092004
# home_team            KC
# game_date     9/20/2009
# Name: 20, dtype: object ['9', '20', '2009']
# game_id      2009092005
# home_team           NYJ
# game_date     9/20/2009
# Name: 21, dtype: object ['9', '20', '2009']
# game_id      2009092006
# home_team           PHI
# game_date     9/20/2009
# Name: 22, dtype: object ['9', '20', '2009']
# game_id      2009092007
# home_team           TEN
# game_date     9/20/2009
# Name: 23, dtype: object ['9', '20', '2009']
# game_id      2009092008
# home_team           WAS
# game_date     9/20/2009
# Name: 24, dtype: object ['9', '20', '2009']
# game_id      2009092009
# home_team           BUF
# game_date     9/20/2009
# Name: 25, dtype: object ['9', '20', '2009']
# game_id      2009092010
# home_team            SF
# game_date     9/20/2009
# Name: 26, dtype: object ['9', '20', '2009']
# game_id      2009092011
# home_team           CHI
# game_date     9/20/2009
# Name: 27, dtype: object ['9', '20', '2009']
# game_id      2009092012
# home_team           DEN
# game_date     9/20/2009
# Name: 28, dtype: object ['9', '20', '2009']
# game_id      2009092013
# home_team            SD
# game_date     9/20/2009
# Name: 29, dtype: object ['9', '20', '2009']
# game_id      2009092014
# home_team           DAL
# game_date     9/20/2009
# Name: 30, dtype: object ['9', '20', '2009']
# game_id      2009092100
# home_team           MIA
# game_date     9/21/2009
# Name: 31, dtype: object ['9', '21', '2009']
# game_id      2009092700
# home_team           BAL
# game_date     9/27/2009
# Name: 32, dtype: object ['9', '27', '2009']
# game_id      2009092701
# home_team           CIN
# game_date     9/27/2009
# Name: 33, dtype: object ['9', '27', '2009']
# game_id      2009092702
# home_team           DET
# game_date     9/27/2009
# Name: 34, dtype: object ['9', '27', '2009']
# game_id      2009092703
# home_team           HOU
# game_date     9/27/2009
# Name: 35, dtype: object ['9', '27', '2009']
# game_id      2009092704
# home_team           MIN
# game_date     9/27/2009
# Name: 36, dtype: object ['9', '27', '2009']
# game_id      2009092705
# home_team            NE
# game_date     9/27/2009
# Name: 37, dtype: object ['9', '27', '2009']
# game_id      2009092706
# home_team           PHI
# game_date     9/27/2009
# Name: 38, dtype: object ['9', '27', '2009']
# game_id      2009092707
# home_team           STL
# game_date     9/27/2009
# Name: 39, dtype: object ['9', '27', '2009']
# game_id      2009092708
# home_team            TB
# game_date     9/27/2009
# Name: 40, dtype: object ['9', '27', '2009']
# game_id      2009092709
# home_team           BUF
# game_date     9/27/2009
# Name: 41, dtype: object ['9', '27', '2009']
# game_id      2009092710
# home_team           SEA
# game_date     9/27/2009
# Name: 42, dtype: object ['9', '27', '2009']
# game_id      2009092711
# home_team           NYJ
# game_date     9/27/2009
# Name: 43, dtype: object ['9', '27', '2009']
# game_id      2009092712
# home_team           OAK
# game_date     9/27/2009
# Name: 44, dtype: object ['9', '27', '2009']
# game_id      2009092713
# home_team            SD
# game_date     9/27/2009
# Name: 45, dtype: object ['9', '27', '2009']
# game_id      2009092714
# home_team           ARI
# game_date     9/27/2009
# Name: 46, dtype: object ['9', '27', '2009']
# game_id      2009092800
# home_team           DAL
# game_date     9/28/2009
# Name: 47, dtype: object ['9', '28', '2009']
# game_id      2009100400
# home_team           CHI
# game_date     10/4/2009
# Name: 48, dtype: object ['10', '4', '2009']
# game_id      2009100401
# home_team           CLE
# game_date     10/4/2009
# Name: 49, dtype: object ['10', '4', '2009']
# game_id      2009100402
# home_team           HOU
# game_date     10/4/2009
# Name: 50, dtype: object ['10', '4', '2009']
# game_id      2009100403
# home_team           IND
# game_date     10/4/2009
# Name: 51, dtype: object ['10', '4', '2009']
# game_id      2009100404
# home_team           JAX
# game_date     10/4/2009
# Name: 52, dtype: object ['10', '4', '2009']
# game_id      2009100405
# home_team            KC
# game_date     10/4/2009
# Name: 53, dtype: object ['10', '4', '2009']
# game_id      2009100406
# home_team            NE
# game_date     10/4/2009
# Name: 54, dtype: object ['10', '4', '2009']
# game_id      2009100407
# home_team           WAS
# game_date     10/4/2009
# Name: 55, dtype: object ['10', '4', '2009']
# game_id      2009100408
# home_team           MIA
# game_date     10/4/2009
# Name: 56, dtype: object ['10', '4', '2009']
# game_id      2009100409
# home_team            NO
# game_date     10/4/2009
# Name: 57, dtype: object ['10', '4', '2009']
# game_id      2009100410
# home_team           DEN
# game_date     10/4/2009
# Name: 58, dtype: object ['10', '4', '2009']
# game_id      2009100411
# home_team            SF
# game_date     10/4/2009
# Name: 59, dtype: object ['10', '4', '2009']
# game_id      2009100412
# home_team           PIT
# game_date     10/4/2009
# Name: 60, dtype: object ['10', '4', '2009']
# game_id      2009100500
# home_team           MIN
# game_date     10/5/2009
# Name: 61, dtype: object ['10', '5', '2009']
# game_id      2009101100
# home_team           BAL
# game_date    10/11/2009
# Name: 62, dtype: object ['10', '11', '2009']
# game_id      2009101101
# home_team           BUF
# game_date    10/11/2009
# Name: 63, dtype: object ['10', '11', '2009']
# game_id      2009101102
# home_team           CAR
# game_date    10/11/2009
# Name: 64, dtype: object ['10', '11', '2009']
# game_id      2009101103
# home_team           DET
# game_date    10/11/2009
# Name: 65, dtype: object ['10', '11', '2009']
# game_id      2009101104
# home_team            KC
# game_date    10/11/2009
# Name: 66, dtype: object ['10', '11', '2009']
# game_id      2009101105
# home_team           NYG
# game_date    10/11/2009
# Name: 67, dtype: object ['10', '11', '2009']
# game_id      2009101106
# home_team           PHI
# game_date    10/11/2009
# Name: 68, dtype: object ['10', '11', '2009']
# game_id      2009101107
# home_team           STL
# game_date    10/11/2009
# Name: 69, dtype: object ['10', '11', '2009']
# game_id      2009101108
# home_team            SF
# game_date    10/11/2009
# Name: 70, dtype: object ['10', '11', '2009']
# game_id      2009101109
# home_team           ARI
# game_date    10/11/2009
# Name: 71, dtype: object ['10', '11', '2009']
# game_id      2009101110
# home_team           DEN
# game_date    10/11/2009
# Name: 72, dtype: object ['10', '11', '2009']
# game_id      2009101111
# home_team           SEA
# game_date    10/11/2009
# Name: 73, dtype: object ['10', '11', '2009']
# game_id      2009101112
# home_team           TEN
# game_date    10/11/2009
# Name: 74, dtype: object ['10', '11', '2009']
# game_id      2009101200
# home_team           MIA
# game_date    10/12/2009
# Name: 75, dtype: object ['10', '12', '2009']
# game_id      2009101800
# home_team           CIN
# game_date    10/18/2009
# Name: 76, dtype: object ['10', '18', '2009']
# game_id      2009101801
# home_team            GB
# game_date    10/18/2009
# Name: 77, dtype: object ['10', '18', '2009']
# game_id      2009101802
# home_team           JAX
# game_date    10/18/2009
# Name: 78, dtype: object ['10', '18', '2009']
# game_id      2009101803
# home_team           MIN
# game_date    10/18/2009
# Name: 79, dtype: object ['10', '18', '2009']
# game_id      2009101804
# home_team            NO
# game_date    10/18/2009
# Name: 80, dtype: object ['10', '18', '2009']
# game_id      2009101805
# home_team           PIT
# game_date    10/18/2009
# Name: 81, dtype: object ['10', '18', '2009']
# game_id      2009101806
# home_team            TB
# game_date    10/18/2009
# Name: 82, dtype: object ['10', '18', '2009']
# game_id      2009101807
# home_team           WAS
# game_date    10/18/2009
# Name: 83, dtype: object ['10', '18', '2009']
# game_id      2009101808
# home_team           OAK
# game_date    10/18/2009
# Name: 84, dtype: object ['10', '18', '2009']
# game_id      2009101809
# home_team           SEA
# game_date    10/18/2009
# Name: 85, dtype: object ['10', '18', '2009']
# game_id      2009101810
# home_team            NE
# game_date    10/18/2009
# Name: 86, dtype: object ['10', '18', '2009']
# game_id      2009101811
# home_team           NYJ
# game_date    10/18/2009
# Name: 87, dtype: object ['10', '18', '2009']
# game_id      2009101812
# home_team           ATL
# game_date    10/18/2009
# Name: 88, dtype: object ['10', '18', '2009']
# game_id      2009101900
# home_team            SD
# game_date    10/19/2009
# Name: 89, dtype: object ['10', '19', '2009']
# game_id      2009102500
# home_team           CIN
# game_date    10/25/2009
# Name: 90, dtype: object ['10', '25', '2009']
# game_id      2009102501
# home_team           CLE
# game_date    10/25/2009
# Name: 91, dtype: object ['10', '25', '2009']
# game_id      2009102502
# home_team           HOU
# game_date    10/25/2009
# Name: 92, dtype: object ['10', '25', '2009']
# game_id      2009102503
# home_team            KC
# game_date    10/25/2009
# Name: 93, dtype: object ['10', '25', '2009']
# game_id      2009102504
# home_team           PIT
# game_date    10/25/2009
# Name: 94, dtype: object ['10', '25', '2009']
# game_id      2009102505
# home_team           STL
# game_date    10/25/2009
# Name: 95, dtype: object ['10', '25', '2009']
# game_id      2009102506
# home_team            TB
# game_date    10/25/2009
# Name: 96, dtype: object ['10', '25', '2009']
# game_id      2009102507
# home_team           CAR
# game_date    10/25/2009
# Name: 97, dtype: object ['10', '25', '2009']
# game_id      2009102508
# home_team           OAK
# game_date    10/25/2009
# Name: 98, dtype: object ['10', '25', '2009']
# game_id      2009102509
# home_team           DAL
# game_date    10/25/2009
# Name: 99, dtype: object ['10', '25', '2009']
# game_id      2009102510
# home_team           MIA
# game_date    10/25/2009
# Name: 100, dtype: object ['10', '25', '2009']
# game_id      2009102511
# home_team           NYG
# game_date    10/25/2009
# Name: 101, dtype: object ['10', '25', '2009']
# game_id      2009102600
# home_team           WAS
# game_date    10/26/2009
# Name: 102, dtype: object ['10', '26', '2009']
# game_id      2009110100
# home_team           BAL
# game_date     11/1/2009
# Name: 103, dtype: object ['11', '1', '2009']
# game_id      2009110101
# home_team           BUF
# game_date     11/1/2009
# Name: 104, dtype: object ['11', '1', '2009']
# game_id      2009110102
# home_team           CHI
# game_date     11/1/2009
# Name: 105, dtype: object ['11', '1', '2009']
# game_id      2009110103
# home_team           DAL
# game_date     11/1/2009
# Name: 106, dtype: object ['11', '1', '2009']
# game_id      2009110104
# home_team           DET
# game_date     11/1/2009
# Name: 107, dtype: object ['11', '1', '2009']
# game_id      2009110105
# home_team            GB
# game_date     11/1/2009
# Name: 108, dtype: object ['11', '1', '2009']
# game_id      2009110106
# home_team           IND
# game_date     11/1/2009
# Name: 109, dtype: object ['11', '1', '2009']
# game_id      2009110107
# home_team           NYJ
# game_date     11/1/2009
# Name: 110, dtype: object ['11', '1', '2009']
# game_id      2009110108
# home_team            SD
# game_date     11/1/2009
# Name: 111, dtype: object ['11', '1', '2009']
# game_id      2009110109
# home_team           TEN
# game_date     11/1/2009
# Name: 112, dtype: object ['11', '1', '2009']
# game_id      2009110110
# home_team           ARI
# game_date     11/1/2009
# Name: 113, dtype: object ['11', '1', '2009']
# game_id      2009110111
# home_team           PHI
# game_date     11/1/2009
# Name: 114, dtype: object ['11', '1', '2009']
# game_id      2009110200
# home_team            NO
# game_date     11/2/2009
# Name: 115, dtype: object ['11', '2', '2009']
# game_id      2009110800
# home_team           ATL
# game_date     11/8/2009
# Name: 116, dtype: object ['11', '8', '2009']
# game_id      2009110801
# home_team           CHI
# game_date     11/8/2009
# Name: 117, dtype: object ['11', '8', '2009']
# game_id      2009110802
# home_team           CIN
# game_date     11/8/2009
# Name: 118, dtype: object ['11', '8', '2009']
# game_id      2009110803
# home_team           IND
# game_date     11/8/2009
# Name: 119, dtype: object ['11', '8', '2009']
# game_id      2009110804
# home_team           JAX
# game_date     11/8/2009
# Name: 120, dtype: object ['11', '8', '2009']
# game_id      2009110805
# home_team            NE
# game_date     11/8/2009
# Name: 121, dtype: object ['11', '8', '2009']
# game_id      2009110806
# home_team            TB
# game_date     11/8/2009
# Name: 122, dtype: object ['11', '8', '2009']
# game_id      2009110807
# home_team            NO
# game_date     11/8/2009
# Name: 123, dtype: object ['11', '8', '2009']
# game_id      2009110808
# home_team           SEA
# game_date     11/8/2009
# Name: 124, dtype: object ['11', '8', '2009']
# game_id      2009110809
# home_team           NYG
# game_date     11/8/2009
# Name: 125, dtype: object ['11', '8', '2009']
# game_id      2009110810
# home_team            SF
# game_date     11/8/2009
# Name: 126, dtype: object ['11', '8', '2009']
# game_id      2009110811
# home_team           PHI
# game_date     11/8/2009
# Name: 127, dtype: object ['11', '8', '2009']
# game_id      2009110900
# home_team           DEN
# game_date     11/9/2009
# Name: 128, dtype: object ['11', '9', '2009']
# game_id      2009111200
# home_team            SF
# game_date    11/12/2009
# Name: 129, dtype: object ['11', '12', '2009']
# game_id      2009111500
# home_team           CAR
# game_date    11/15/2009
# Name: 130, dtype: object ['11', '15', '2009']
# game_id      2009111501
# home_team           MIA
# game_date    11/15/2009
# Name: 131, dtype: object ['11', '15', '2009']
# game_id      2009111502
# home_team           MIN
# game_date    11/15/2009
# Name: 132, dtype: object ['11', '15', '2009']
# game_id      2009111503
# home_team           NYJ
# game_date    11/15/2009
# Name: 133, dtype: object ['11', '15', '2009']
# game_id      2009111504
# home_team           PIT
# game_date    11/15/2009
# Name: 134, dtype: object ['11', '15', '2009']
# game_id      2009111505
# home_team           STL
# game_date    11/15/2009
# Name: 135, dtype: object ['11', '15', '2009']
# game_id      2009111506
# home_team           TEN
# game_date    11/15/2009
# Name: 136, dtype: object ['11', '15', '2009']
# game_id      2009111507
# home_team           WAS
# game_date    11/15/2009
# Name: 137, dtype: object ['11', '15', '2009']
# game_id      2009111508
# home_team           OAK
# game_date    11/15/2009
# Name: 138, dtype: object ['11', '15', '2009']
# game_id      2009111509
# home_team           ARI
# game_date    11/15/2009
# Name: 139, dtype: object ['11', '15', '2009']
# game_id      2009111510
# home_team            GB
# game_date    11/15/2009
# Name: 140, dtype: object ['11', '15', '2009']
# game_id      2009111511
# home_team            SD
# game_date    11/15/2009
# Name: 141, dtype: object ['11', '15', '2009']
# game_id      2009111512
# home_team           IND
# game_date    11/15/2009
# Name: 142, dtype: object ['11', '15', '2009']
# game_id      2009111600
# home_team           CLE
# game_date    11/16/2009
# Name: 143, dtype: object ['11', '16', '2009']
# game_id      2009111900
# home_team           CAR
# game_date    11/19/2009
# Name: 144, dtype: object ['11', '19', '2009']
# game_id      2009112200
# home_team           BAL
# game_date    11/22/2009
# Name: 145, dtype: object ['11', '22', '2009']
# game_id      2009112201
# home_team           DAL
# game_date    11/22/2009
# Name: 146, dtype: object ['11', '22', '2009']
# game_id      2009112202
# home_team           DET
# game_date    11/22/2009
# Name: 147, dtype: object ['11', '22', '2009']
# game_id      2009112203
# home_team            GB
# game_date    11/22/2009
# Name: 148, dtype: object ['11', '22', '2009']
# game_id      2009112204
# home_team           JAX
# game_date    11/22/2009
# Name: 149, dtype: object ['11', '22', '2009']
# game_id      2009112205
# home_team            KC
# game_date    11/22/2009
# Name: 150, dtype: object ['11', '22', '2009']
# game_id      2009112206
# home_team           MIN
# game_date    11/22/2009
# Name: 151, dtype: object ['11', '22', '2009']
# game_id      2009112207
# home_team           NYG
# game_date    11/22/2009
# Name: 152, dtype: object ['11', '22', '2009']
# game_id      2009112208
# home_team            TB
# game_date    11/22/2009
# Name: 153, dtype: object ['11', '22', '2009']
# game_id      2009112209
# home_team           STL
# game_date    11/22/2009
# Name: 154, dtype: object ['11', '22', '2009']
# game_id      2009112210
# home_team           DEN
# game_date    11/22/2009
# Name: 155, dtype: object ['11', '22', '2009']
# game_id      2009112211
# home_team            NE
# game_date    11/22/2009
# Name: 156, dtype: object ['11', '22', '2009']
# game_id      2009112212
# home_team           OAK
# game_date    11/22/2009
# Name: 157, dtype: object ['11', '22', '2009']
# game_id      2009112213
# home_team           CHI
# game_date    11/22/2009
# Name: 158, dtype: object ['11', '22', '2009']
# game_id      2009112300
# home_team           HOU
# game_date    11/23/2009
# Name: 159, dtype: object ['11', '23', '2009']
# game_id      2009112600
# home_team           DET
# game_date    11/26/2009
# Name: 160, dtype: object ['11', '26', '2009']
# game_id      2009112601
# home_team           DAL
# game_date    11/26/2009
# Name: 161, dtype: object ['11', '26', '2009']
# game_id      2009112602
# home_team           DEN
# game_date    11/26/2009
# Name: 162, dtype: object ['11', '26', '2009']
# game_id      2009112900
# home_team           ATL
# game_date    11/29/2009
# Name: 163, dtype: object ['11', '29', '2009']
# game_id      2009112901
# home_team           BUF
# game_date    11/29/2009
# Name: 164, dtype: object ['11', '29', '2009']
# game_id      2009112902
# home_team           CIN
# game_date    11/29/2009
# Name: 165, dtype: object ['11', '29', '2009']
# game_id      2009112903
# home_team           HOU
# game_date    11/29/2009
# Name: 166, dtype: object ['11', '29', '2009']
# game_id      2009112904
# home_team           MIN
# game_date    11/29/2009
# Name: 167, dtype: object ['11', '29', '2009']
# game_id      2009112905
# home_team           NYJ
# game_date    11/29/2009
# Name: 168, dtype: object ['11', '29', '2009']
# game_id      2009112906
# home_team           PHI
# game_date    11/29/2009
# Name: 169, dtype: object ['11', '29', '2009']
# game_id      2009112907
# home_team           STL
# game_date    11/29/2009
# Name: 170, dtype: object ['11', '29', '2009']
# game_id      2009112908
# home_team           TEN
# game_date    11/29/2009
# Name: 171, dtype: object ['11', '29', '2009']
# game_id      2009112909
# home_team            SD
# game_date    11/29/2009
# Name: 172, dtype: object ['11', '29', '2009']
# game_id      2009112910
# home_team            SF
# game_date    11/29/2009
# Name: 173, dtype: object ['11', '29', '2009']
# game_id      2009112911
# home_team           BAL
# game_date    11/29/2009
# Name: 174, dtype: object ['11', '29', '2009']
# game_id      2009113000
# home_team            NO
# game_date    11/30/2009
# Name: 175, dtype: object ['11', '30', '2009']
# game_id      2009120300
# home_team           BUF
# game_date     12/3/2009
# Name: 176, dtype: object ['12', '3', '2009']
# game_id      2009120600
# home_team           ATL
# game_date     12/6/2009
# Name: 177, dtype: object ['12', '6', '2009']
# game_id      2009120601
# home_team           CAR
# game_date     12/6/2009
# Name: 178, dtype: object ['12', '6', '2009']
# game_id      2009120602
# home_team           CHI
# game_date     12/6/2009
# Name: 179, dtype: object ['12', '6', '2009']
# game_id      2009120603
# home_team           CIN
# game_date     12/6/2009
# Name: 180, dtype: object ['12', '6', '2009']
# game_id      2009120604
# home_team           IND
# game_date     12/6/2009
# Name: 181, dtype: object ['12', '6', '2009']
# game_id      2009120605
# home_team           JAX
# game_date     12/6/2009
# Name: 182, dtype: object ['12', '6', '2009']
# game_id      2009120606
# home_team            KC
# game_date     12/6/2009
# Name: 183, dtype: object ['12', '6', '2009']
# game_id      2009120607
# home_team           PIT
# game_date     12/6/2009
# Name: 184, dtype: object ['12', '6', '2009']
# game_id      2009120608
# home_team           WAS
# game_date     12/6/2009
# Name: 185, dtype: object ['12', '6', '2009']
# game_id      2009120609
# home_team           CLE
# game_date     12/6/2009
# Name: 186, dtype: object ['12', '6', '2009']
# game_id      2009120610
# home_team           ARI
# game_date     12/6/2009
# Name: 187, dtype: object ['12', '6', '2009']
# game_id      2009120611
# home_team           NYG
# game_date     12/6/2009
# Name: 188, dtype: object ['12', '6', '2009']
# game_id      2009120612
# home_team           SEA
# game_date     12/6/2009
# Name: 189, dtype: object ['12', '6', '2009']
# game_id      2009120613
# home_team           MIA
# game_date     12/6/2009
# Name: 190, dtype: object ['12', '6', '2009']
# game_id      2009120700
# home_team            GB
# game_date     12/7/2009
# Name: 191, dtype: object ['12', '7', '2009']
# game_id      2009121000
# home_team           CLE
# game_date    12/10/2009
# Name: 192, dtype: object ['12', '10', '2009']
# game_id      2009121300
# home_team           ATL
# game_date    12/13/2009
# Name: 193, dtype: object ['12', '13', '2009']
# game_id      2009121301
# home_team           BAL
# game_date    12/13/2009
# Name: 194, dtype: object ['12', '13', '2009']
# game_id      2009121302
# home_team           CHI
# game_date    12/13/2009
# Name: 195, dtype: object ['12', '13', '2009']
# game_id      2009121303
# home_team           HOU
# game_date    12/13/2009
# Name: 196, dtype: object ['12', '13', '2009']
# game_id      2009121304
# home_team           IND
# game_date    12/13/2009
# Name: 197, dtype: object ['12', '13', '2009']
# game_id      2009121305
# home_team           JAX
# game_date    12/13/2009
# Name: 198, dtype: object ['12', '13', '2009']
# game_id      2009121306
# home_team            KC
# game_date    12/13/2009
# Name: 199, dtype: object ['12', '13', '2009']
# game_id      2009121307
# home_team           MIN
# game_date    12/13/2009
# Name: 200, dtype: object ['12', '13', '2009']
# game_id      2009121308
# home_team            NE
# game_date    12/13/2009
# Name: 201, dtype: object ['12', '13', '2009']
# game_id      2009121309
# home_team            TB
# game_date    12/13/2009
# Name: 202, dtype: object ['12', '13', '2009']
# game_id      2009121310
# home_team           TEN
# game_date    12/13/2009
# Name: 203, dtype: object ['12', '13', '2009']
# game_id      2009121311
# home_team           OAK
# game_date    12/13/2009
# Name: 204, dtype: object ['12', '13', '2009']
# game_id      2009121312
# home_team           DAL
# game_date    12/13/2009
# Name: 205, dtype: object ['12', '13', '2009']
# game_id      2009121313
# home_team           NYG
# game_date    12/13/2009
# Name: 206, dtype: object ['12', '13', '2009']
# game_id      2009121400
# home_team            SF
# game_date    12/14/2009
# Name: 207, dtype: object ['12', '14', '2009']
# game_id      2009121700
# home_team           JAX
# game_date    12/17/2009
# Name: 208, dtype: object ['12', '17', '2009']
# game_id      2009121900
# home_team            NO
# game_date    12/19/2009
# Name: 209, dtype: object ['12', '19', '2009']
# game_id      2009122000
# home_team           BAL
# game_date    12/20/2009
# Name: 210, dtype: object ['12', '20', '2009']
# game_id      2009122001
# home_team           BUF
# game_date    12/20/2009
# Name: 211, dtype: object ['12', '20', '2009']
# game_id      2009122002
# home_team           DET
# game_date    12/20/2009
# Name: 212, dtype: object ['12', '20', '2009']
# game_id      2009122003
# home_team            KC
# game_date    12/20/2009
# Name: 213, dtype: object ['12', '20', '2009']
# game_id      2009122004
# home_team           NYJ
# game_date    12/20/2009
# Name: 214, dtype: object ['12', '20', '2009']
# game_id      2009122005
# home_team           PHI
# game_date    12/20/2009
# Name: 215, dtype: object ['12', '20', '2009']
# game_id      2009122006
# home_team           PIT
# game_date    12/20/2009
# Name: 216, dtype: object ['12', '20', '2009']
# game_id      2009122007
# home_team           STL
# game_date    12/20/2009
# Name: 217, dtype: object ['12', '20', '2009']
# game_id      2009122008
# home_team           TEN
# game_date    12/20/2009
# Name: 218, dtype: object ['12', '20', '2009']
# game_id      2009122009
# home_team           DEN
# game_date    12/20/2009
# Name: 219, dtype: object ['12', '20', '2009']
# game_id      2009122010
# home_team            SD
# game_date    12/20/2009
# Name: 220, dtype: object ['12', '20', '2009']
# game_id      2009122011
# home_team           SEA
# game_date    12/20/2009
# Name: 221, dtype: object ['12', '20', '2009']
# game_id      2009122012
# home_team           CAR
# game_date    12/20/2009
# Name: 222, dtype: object ['12', '20', '2009']
# game_id      2009122100
# home_team           WAS
# game_date    12/21/2009
# Name: 223, dtype: object ['12', '21', '2009']
# game_id      2009122500
# home_team           TEN
# game_date    12/25/2009
# Name: 224, dtype: object ['12', '25', '2009']
# game_id      2009122700
# home_team           ATL
# game_date    12/27/2009
# Name: 225, dtype: object ['12', '27', '2009']
# game_id      2009122701
# home_team           CIN
# game_date    12/27/2009
# Name: 226, dtype: object ['12', '27', '2009']
# game_id      2009122702
# home_team           CLE
# game_date    12/27/2009
# Name: 227, dtype: object ['12', '27', '2009']
# game_id      2009122703
# home_team            GB
# game_date    12/27/2009
# Name: 228, dtype: object ['12', '27', '2009']
# game_id      2009122704
# home_team           MIA
# game_date    12/27/2009
# Name: 229, dtype: object ['12', '27', '2009']
# game_id      2009122705
# home_team           NYG
# game_date    12/27/2009
# Name: 230, dtype: object ['12', '27', '2009']
# game_id      2009122706
# home_team            NE
# game_date    12/27/2009
# Name: 231, dtype: object ['12', '27', '2009']
# game_id      2009122707
# home_team            NO
# game_date    12/27/2009
# Name: 232, dtype: object ['12', '27', '2009']
# game_id      2009122708
# home_team           PHI
# game_date    12/27/2009
# Name: 233, dtype: object ['12', '27', '2009']
# game_id      2009122709
# home_team           PIT
# game_date    12/27/2009
# Name: 234, dtype: object ['12', '27', '2009']
# game_id      2009122710
# home_team           ARI
# game_date    12/27/2009
# Name: 235, dtype: object ['12', '27', '2009']
# game_id      2009122711
# home_team            SF
# game_date    12/27/2009
# Name: 236, dtype: object ['12', '27', '2009']
# game_id      2009122712
# home_team           IND
# game_date    12/27/2009
# Name: 237, dtype: object ['12', '27', '2009']
# game_id      2009122713
# home_team           WAS
# game_date    12/27/2009
# Name: 238, dtype: object ['12', '27', '2009']
# game_id      2009122800
# home_team           CHI
# game_date    12/28/2009
# Name: 239, dtype: object ['12', '28', '2009']
# game_id      2010010300
# home_team           BUF
# game_date      1/3/2010
# Name: 240, dtype: object ['1', '3', '2010']
# game_id      2010010301
# home_team           CAR
# game_date      1/3/2010
# Name: 241, dtype: object ['1', '3', '2010']
# game_id      2010010302
# home_team           CLE
# game_date      1/3/2010
# Name: 242, dtype: object ['1', '3', '2010']
# game_id      2010010303
# home_team           DAL
# game_date      1/3/2010
# Name: 243, dtype: object ['1', '3', '2010']
# game_id      2010010304
# home_team           DET
# game_date      1/3/2010
# Name: 244, dtype: object ['1', '3', '2010']
# game_id      2010010305
# home_team           HOU
# game_date      1/3/2010
# Name: 245, dtype: object ['1', '3', '2010']
# game_id      2010010306
# home_team           MIA
# game_date      1/3/2010
# Name: 246, dtype: object ['1', '3', '2010']
# game_id      2010010307
# home_team           MIN
# game_date      1/3/2010
# Name: 247, dtype: object ['1', '3', '2010']
# game_id      2010010308
# home_team           NYJ
# game_date      1/3/2010
# Name: 248, dtype: object ['1', '3', '2010']
# game_id      2010010309
# home_team           STL
# game_date      1/3/2010
# Name: 249, dtype: object ['1', '3', '2010']
# game_id      2010010310
# home_team            TB
# game_date      1/3/2010
# Name: 250, dtype: object ['1', '3', '2010']
# game_id      2010010311
# home_team           ARI
# game_date      1/3/2010
# Name: 251, dtype: object ['1', '3', '2010']
# game_id      2010010312
# home_team           DEN
# game_date      1/3/2010
# Name: 252, dtype: object ['1', '3', '2010']
# game_id      2010010313
# home_team           OAK
# game_date      1/3/2010
# Name: 253, dtype: object ['1', '3', '2010']
# game_id      2010010314
# home_team            SD
# game_date      1/3/2010
# Name: 254, dtype: object ['1', '3', '2010']
# game_id      2010010315
# home_team           SEA
# game_date      1/3/2010
# Name: 255, dtype: object ['1', '3', '2010']
# game_id      2010090900
# home_team            NO
# game_date      9/9/2010
# Name: 256, dtype: object ['9', '9', '2010']
# game_id      2010091200
# home_team            TB
# game_date     9/12/2010
# Name: 257, dtype: object ['9', '12', '2010']
# game_id      2010091201
# home_team           BUF
# game_date     9/12/2010
# Name: 258, dtype: object ['9', '12', '2010']
# game_id      2010091202
# home_team            NE
# game_date     9/12/2010
# Name: 259, dtype: object ['9', '12', '2010']
# game_id      2010091203
# home_team           HOU
# game_date     9/12/2010
# Name: 260, dtype: object ['9', '12', '2010']
# game_id      2010091204
# home_team           JAX
# game_date     9/12/2010
# Name: 261, dtype: object ['9', '12', '2010']
# game_id      2010091205
# home_team           TEN
# game_date     9/12/2010
# Name: 262, dtype: object ['9', '12', '2010']
# game_id      2010091206
# home_team           NYG
# game_date     9/12/2010
# Name: 263, dtype: object ['9', '12', '2010']
# game_id      2010091207
# home_team           CHI
# game_date     9/12/2010
# Name: 264, dtype: object ['9', '12', '2010']
# game_id      2010091208
# home_team           STL
# game_date     9/12/2010
# Name: 265, dtype: object ['9', '12', '2010']
# game_id      2010091209
# home_team           PIT
# game_date     9/12/2010
# Name: 266, dtype: object ['9', '12', '2010']
# game_id      2010091210
# home_team           PHI
# game_date     9/12/2010
# Name: 267, dtype: object ['9', '12', '2010']
# game_id      2010091211
# home_team           SEA
# game_date     9/12/2010
# Name: 268, dtype: object ['9', '12', '2010']
# game_id      2010091212
# home_team           WAS
# game_date     9/12/2010
# Name: 269, dtype: object ['9', '12', '2010']
# game_id      2010091300
# home_team           NYJ
# game_date     9/13/2010
# Name: 270, dtype: object ['9', '13', '2010']
# game_id      2010091301
# home_team            KC
# game_date     9/13/2010
# Name: 271, dtype: object ['9', '13', '2010']
# game_id      2010091900
# home_team           WAS
# game_date     9/19/2010
# Name: 272, dtype: object ['9', '19', '2010']
# game_id      2010091901
# home_team            GB
# game_date     9/19/2010
# Name: 273, dtype: object ['9', '19', '2010']
# game_id      2010091902
# home_team           MIN
# game_date     9/19/2010
# Name: 274, dtype: object ['9', '19', '2010']
# game_id      2010091903
# home_team           CLE
# game_date     9/19/2010
# Name: 275, dtype: object ['9', '19', '2010']
# game_id      2010091904
# home_team           TEN
# game_date     9/19/2010
# Name: 276, dtype: object ['9', '19', '2010']
# game_id      2010091905
# home_team           DAL
# game_date     9/19/2010
# Name: 277, dtype: object ['9', '19', '2010']
# game_id      2010091906
# home_team           DET
# game_date     9/19/2010
# Name: 278, dtype: object ['9', '19', '2010']
# game_id      2010091907
# home_team           ATL
# game_date     9/19/2010
# Name: 279, dtype: object ['9', '19', '2010']
# game_id      2010091908
# home_team           CAR
# game_date     9/19/2010
# Name: 280, dtype: object ['9', '19', '2010']
# game_id      2010091909
# home_team           DEN
# game_date     9/19/2010
# Name: 281, dtype: object ['9', '19', '2010']
# game_id      2010091910
# home_team           OAK
# game_date     9/19/2010
# Name: 282, dtype: object ['9', '19', '2010']
# game_id      2010091911
# home_team           NYJ
# game_date     9/19/2010
# Name: 283, dtype: object ['9', '19', '2010']
# game_id      2010091912
# home_team           CIN
# game_date     9/19/2010
# Name: 284, dtype: object ['9', '19', '2010']
# game_id      2010091913
# home_team            SD
# game_date     9/19/2010
# Name: 285, dtype: object ['9', '19', '2010']
# game_id      2010091914
# home_team           IND
# game_date     9/19/2010
# Name: 286, dtype: object ['9', '19', '2010']
# game_id      2010092000
# home_team            SF
# game_date     9/20/2010
# Name: 287, dtype: object ['9', '20', '2010']
# game_id      2010092600
# home_team           NYG
# game_date     9/26/2010
# Name: 288, dtype: object ['9', '26', '2010']
# game_id      2010092601
# home_team           CAR
# game_date     9/26/2010
# Name: 289, dtype: object ['9', '26', '2010']
# game_id      2010092602
# home_team            TB
# game_date     9/26/2010
# Name: 290, dtype: object ['9', '26', '2010']
# game_id      2010092603
# home_team            NE
# game_date     9/26/2010
# Name: 291, dtype: object ['9', '26', '2010']
# game_id      2010092604
# home_team           BAL
# game_date     9/26/2010
# Name: 292, dtype: object ['9', '26', '2010']
# game_id      2010092605
# home_team           MIN
# game_date     9/26/2010
# Name: 293, dtype: object ['9', '26', '2010']
# game_id      2010092606
# home_team            NO
# game_date     9/26/2010
# Name: 294, dtype: object ['9', '26', '2010']
# game_id      2010092607
# home_team           STL
# game_date     9/26/2010
# Name: 295, dtype: object ['9', '26', '2010']
# game_id      2010092608
# home_team           HOU
# game_date     9/26/2010
# Name: 296, dtype: object ['9', '26', '2010']
# game_id      2010092609
# home_team            KC
# game_date     9/26/2010
# Name: 297, dtype: object ['9', '26', '2010']
# game_id      2010092610
# home_team           JAX
# game_date     9/26/2010
# Name: 298, dtype: object ['9', '26', '2010']
# game_id      2010092611
# home_team           DEN
# game_date     9/26/2010
# Name: 299, dtype: object ['9', '26', '2010']
# game_id      2010092612
# home_team           ARI
# game_date     9/26/2010
# Name: 300, dtype: object ['9', '26', '2010']
# game_id      2010092613
# home_team           SEA
# game_date     9/26/2010
# Name: 301, dtype: object ['9', '26', '2010']
# game_id      2010092614
# home_team           MIA
# game_date     9/26/2010
# Name: 302, dtype: object ['9', '26', '2010']
# game_id      2010092700
# home_team           CHI
# game_date     9/27/2010
# Name: 303, dtype: object ['9', '27', '2010']
# game_id      2010100300
# home_team           BUF
# game_date     10/3/2010
# Name: 304, dtype: object ['10', '3', '2010']
# game_id      2010100301
# home_team           CLE
# game_date     10/3/2010
# Name: 305, dtype: object ['10', '3', '2010']
# game_id      2010100302
# home_team           PIT
# game_date     10/3/2010
# Name: 306, dtype: object ['10', '3', '2010']
# game_id      2010100303
# home_team           TEN
# game_date     10/3/2010
# Name: 307, dtype: object ['10', '3', '2010']
# game_id      2010100304
# home_team            GB
# game_date     10/3/2010
# Name: 308, dtype: object ['10', '3', '2010']
# game_id      2010100305
# home_team           ATL
# game_date     10/3/2010
# Name: 309, dtype: object ['10', '3', '2010']
# game_id      2010100306
# home_team            NO
# game_date     10/3/2010
# Name: 310, dtype: object ['10', '3', '2010']
# game_id      2010100307
# home_team           STL
# game_date     10/3/2010
# Name: 311, dtype: object ['10', '3', '2010']
# game_id      2010100308
# home_team           JAX
# game_date     10/3/2010
# Name: 312, dtype: object ['10', '3', '2010']
# game_id      2010100309
# home_team           OAK
# game_date     10/3/2010
# Name: 313, dtype: object ['10', '3', '2010']
# game_id      2010100310
# home_team           PHI
# game_date     10/3/2010
# Name: 314, dtype: object ['10', '3', '2010']
# game_id      2010100311
# home_team            SD
# game_date     10/3/2010
# Name: 315, dtype: object ['10', '3', '2010']
# game_id      2010100312
# home_team           NYG
# game_date     10/3/2010
# Name: 316, dtype: object ['10', '3', '2010']
# game_id      2010100400
# home_team           MIA
# game_date     10/4/2010
# Name: 317, dtype: object ['10', '4', '2010']
# game_id      2010101000
# home_team           BUF
# game_date    10/10/2010
# Name: 318, dtype: object ['10', '10', '2010']
# game_id      2010101001
# home_team           BAL
# game_date    10/10/2010
# Name: 319, dtype: object ['10', '10', '2010']
# game_id      2010101002
# home_team           IND
# game_date    10/10/2010
# Name: 320, dtype: object ['10', '10', '2010']
# game_id      2010101003
# home_team           WAS
# game_date    10/10/2010
# Name: 321, dtype: object ['10', '10', '2010']
# game_id      2010101004
# home_team           DET
# game_date    10/10/2010
# Name: 322, dtype: object ['10', '10', '2010']
# game_id      2010101005
# home_team           CAR
# game_date    10/10/2010
# Name: 323, dtype: object ['10', '10', '2010']
# game_id      2010101006
# home_team           CIN
# game_date    10/10/2010
# Name: 324, dtype: object ['10', '10', '2010']
# game_id      2010101007
# home_team           CLE
# game_date    10/10/2010
# Name: 325, dtype: object ['10', '10', '2010']
# game_id      2010101008
# home_team           HOU
# game_date    10/10/2010
# Name: 326, dtype: object ['10', '10', '2010']
# game_id      2010101009
# home_team           ARI
# game_date    10/10/2010
# Name: 327, dtype: object ['10', '10', '2010']
# game_id      2010101010
# home_team           DAL
# game_date    10/10/2010
# Name: 328, dtype: object ['10', '10', '2010']
# game_id      2010101011
# home_team           OAK
# game_date    10/10/2010
# Name: 329, dtype: object ['10', '10', '2010']
# game_id      2010101012
# home_team            SF
# game_date    10/10/2010
# Name: 330, dtype: object ['10', '10', '2010']
# game_id      2010101100
# home_team           NYJ
# game_date    10/11/2010
# Name: 331, dtype: object ['10', '11', '2010']
# game_id      2010101700
# home_team            GB
# game_date    10/17/2010
# Name: 332, dtype: object ['10', '17', '2010']
# game_id      2010101701
# home_team           STL
# game_date    10/17/2010
# Name: 333, dtype: object ['10', '17', '2010']
# game_id      2010101702
# home_team            NE
# game_date    10/17/2010
# Name: 334, dtype: object ['10', '17', '2010']
# game_id      2010101703
# home_team           PIT
# game_date    10/17/2010
# Name: 335, dtype: object ['10', '17', '2010']
# game_id      2010101704
# home_team           HOU
# game_date    10/17/2010
# Name: 336, dtype: object ['10', '17', '2010']
# game_id      2010101705
# home_team           NYG
# game_date    10/17/2010
# Name: 337, dtype: object ['10', '17', '2010']
# game_id      2010101706
# home_team           PHI
# game_date    10/17/2010
# Name: 338, dtype: object ['10', '17', '2010']
# game_id      2010101707
# home_team           CHI
# game_date    10/17/2010
# Name: 339, dtype: object ['10', '17', '2010']
# game_id      2010101708
# home_team            TB
# game_date    10/17/2010
# Name: 340, dtype: object ['10', '17', '2010']
# game_id      2010101709
# home_team           DEN
# game_date    10/17/2010
# Name: 341, dtype: object ['10', '17', '2010']
# game_id      2010101710
# home_team            SF
# game_date    10/17/2010
# Name: 342, dtype: object ['10', '17', '2010']
# game_id      2010101711
# home_team           MIN
# game_date    10/17/2010
# Name: 343, dtype: object ['10', '17', '2010']
# game_id      2010101712
# home_team           WAS
# game_date    10/17/2010
# Name: 344, dtype: object ['10', '17', '2010']
# game_id      2010101800
# home_team           JAX
# game_date    10/18/2010
# Name: 345, dtype: object ['10', '18', '2010']
# game_id      2010102400
# home_team           ATL
# game_date    10/24/2010
# Name: 346, dtype: object ['10', '24', '2010']
# game_id      2010102401
# home_team           MIA
# game_date    10/24/2010
# Name: 347, dtype: object ['10', '24', '2010']
# game_id      2010102402
# home_team           BAL
# game_date    10/24/2010
# Name: 348, dtype: object ['10', '24', '2010']
# game_id      2010102403
# home_team            KC
# game_date    10/24/2010
# Name: 349, dtype: object ['10', '24', '2010']
# game_id      2010102404
# home_team            NO
# game_date    10/24/2010
# Name: 350, dtype: object ['10', '24', '2010']
# game_id      2010102405
# home_team           CHI
# game_date    10/24/2010
# Name: 351, dtype: object ['10', '24', '2010']
# game_id      2010102406
# home_team           CAR
# game_date    10/24/2010
# Name: 352, dtype: object ['10', '24', '2010']
# game_id      2010102407
# home_team            TB
# game_date    10/24/2010
# Name: 353, dtype: object ['10', '24', '2010']
# game_id      2010102408
# home_team           TEN
# game_date    10/24/2010
# Name: 354, dtype: object ['10', '24', '2010']
# game_id      2010102409
# home_team           SEA
# game_date    10/24/2010
# Name: 355, dtype: object ['10', '24', '2010']
# game_id      2010102410
# home_team            SD
# game_date    10/24/2010
# Name: 356, dtype: object ['10', '24', '2010']
# game_id      2010102411
# home_team           DEN
# game_date    10/24/2010
# Name: 357, dtype: object ['10', '24', '2010']
# game_id      2010102412
# home_team            GB
# game_date    10/24/2010
# Name: 358, dtype: object ['10', '24', '2010']
# game_id      2010102500
# home_team           DAL
# game_date    10/25/2010
# Name: 359, dtype: object ['10', '25', '2010']
# game_id      2010103100
# home_team            SF
# game_date    10/31/2010
# Name: 360, dtype: object ['10', '31', '2010']
# game_id      2010103101
# home_team           DAL
# game_date    10/31/2010
# Name: 361, dtype: object ['10', '31', '2010']
# game_id      2010103102
# home_team           CIN
# game_date    10/31/2010
# Name: 362, dtype: object ['10', '31', '2010']
# game_id      2010103103
# home_team            KC
# game_date    10/31/2010
# Name: 363, dtype: object ['10', '31', '2010']
# game_id      2010103104
# home_team           DET
# game_date    10/31/2010
# Name: 364, dtype: object ['10', '31', '2010']
# game_id      2010103105
# home_team           STL
# game_date    10/31/2010
# Name: 365, dtype: object ['10', '31', '2010']
# game_id      2010103106
# home_team           NYJ
# game_date    10/31/2010
# Name: 366, dtype: object ['10', '31', '2010']
# game_id      2010103107
# home_team            SD
# game_date    10/31/2010
# Name: 367, dtype: object ['10', '31', '2010']
# game_id      2010103108
# home_team            NE
# game_date    10/31/2010
# Name: 368, dtype: object ['10', '31', '2010']
# game_id      2010103109
# home_team           ARI
# game_date    10/31/2010
# Name: 369, dtype: object ['10', '31', '2010']
# game_id      2010103110
# home_team           OAK
# game_date    10/31/2010
# Name: 370, dtype: object ['10', '31', '2010']
# game_id      2010103111
# home_team            NO
# game_date    10/31/2010
# Name: 371, dtype: object ['10', '31', '2010']
# game_id      2010110100
# home_team           IND
# game_date     11/1/2010
# Name: 372, dtype: object ['11', '1', '2010']
# game_id      2010110700
# home_team           DET
# game_date     11/7/2010
# Name: 373, dtype: object ['11', '7', '2010']
# game_id      2010110701
# home_team           BAL
# game_date     11/7/2010
# Name: 374, dtype: object ['11', '7', '2010']
# game_id      2010110702
# home_team           CLE
# game_date     11/7/2010
# Name: 375, dtype: object ['11', '7', '2010']
# game_id      2010110703
# home_team           HOU
# game_date     11/7/2010
# Name: 376, dtype: object ['11', '7', '2010']
# game_id      2010110704
# home_team           BUF
# game_date     11/7/2010
# Name: 377, dtype: object ['11', '7', '2010']
# game_id      2010110705
# home_team           MIN
# game_date     11/7/2010
# Name: 378, dtype: object ['11', '7', '2010']
# game_id      2010110706
# home_team           ATL
# game_date     11/7/2010
# Name: 379, dtype: object ['11', '7', '2010']
# game_id      2010110707
# home_team           CAR
# game_date     11/7/2010
# Name: 380, dtype: object ['11', '7', '2010']
# game_id      2010110708
# home_team           SEA
# game_date     11/7/2010
# Name: 381, dtype: object ['11', '7', '2010']
# game_id      2010110709
# home_team           PHI
# game_date     11/7/2010
# Name: 382, dtype: object ['11', '7', '2010']
# game_id      2010110710
# home_team           OAK
# game_date     11/7/2010
# Name: 383, dtype: object ['11', '7', '2010']
# game_id      2010110711
# home_team            GB
# game_date     11/7/2010
# Name: 384, dtype: object ['11', '7', '2010']
# game_id      2010110800
# home_team           CIN
# game_date     11/8/2010
# Name: 385, dtype: object ['11', '8', '2010']
# game_id      2010111100
# home_team           ATL
# game_date    11/11/2010
# Name: 386, dtype: object ['11', '11', '2010']
# game_id      2010111400
# home_team           MIA
# game_date    11/14/2010
# Name: 387, dtype: object ['11', '14', '2010']
# game_id      2010111401
# home_team           CLE
# game_date    11/14/2010
# Name: 388, dtype: object ['11', '14', '2010']
# game_id      2010111402
# home_team           IND
# game_date    11/14/2010
# Name: 389, dtype: object ['11', '14', '2010']
# game_id      2010111403
# home_team           JAX
# game_date    11/14/2010
# Name: 390, dtype: object ['11', '14', '2010']
# game_id      2010111404
# home_team           CHI
# game_date    11/14/2010
# Name: 391, dtype: object ['11', '14', '2010']
# game_id      2010111405
# home_team            TB
# game_date    11/14/2010
# Name: 392, dtype: object ['11', '14', '2010']
# game_id      2010111406
# home_team           BUF
# game_date    11/14/2010
# Name: 393, dtype: object ['11', '14', '2010']
# game_id      2010111407
# home_team           DEN
# game_date    11/14/2010
# Name: 394, dtype: object ['11', '14', '2010']
# game_id      2010111408
# home_team           NYG
# game_date    11/14/2010
# Name: 395, dtype: object ['11', '14', '2010']
# game_id      2010111409
# home_team           ARI
# game_date    11/14/2010
# Name: 396, dtype: object ['11', '14', '2010']
# game_id      2010111410
# home_team            SF
# game_date    11/14/2010
# Name: 397, dtype: object ['11', '14', '2010']
# game_id      2010111411
# home_team           PIT
# game_date    11/14/2010
# Name: 398, dtype: object ['11', '14', '2010']
# game_id      2010111500
# home_team           WAS
# game_date    11/15/2010
# Name: 399, dtype: object ['11', '15', '2010']
# game_id      2010111800
# home_team           MIA
# game_date    11/18/2010
# Name: 400, dtype: object ['11', '18', '2010']
# game_id      2010112100
# home_team           CAR
# game_date    11/21/2010
# Name: 401, dtype: object ['11', '21', '2010']
# game_id      2010112101
# home_team           NYJ
# game_date    11/21/2010
# Name: 402, dtype: object ['11', '21', '2010']
# game_id      2010112102
# home_team           CIN
# game_date    11/21/2010
# Name: 403, dtype: object ['11', '21', '2010']
# game_id      2010112103
# home_team           PIT
# game_date    11/21/2010
# Name: 404, dtype: object ['11', '21', '2010']
# game_id      2010112104
# home_team           JAX
# game_date    11/21/2010
# Name: 405, dtype: object ['11', '21', '2010']
# game_id      2010112105
# home_team           DAL
# game_date    11/21/2010
# Name: 406, dtype: object ['11', '21', '2010']
# game_id      2010112106
# home_team           MIN
# game_date    11/21/2010
# Name: 407, dtype: object ['11', '21', '2010']
# game_id      2010112107
# home_team            NO
# game_date    11/21/2010
# Name: 408, dtype: object ['11', '21', '2010']
# game_id      2010112108
# home_team           TEN
# ...
# Name: 1929, dtype: object ['11', '13', '2016']
# game_id      2016111306
# home_team            TB
# game_date    11/13/2016
# Name: 1930, dtype: object ['11', '13', '2016']
# game_id      2016111307
# home_team           TEN
# game_date    11/13/2016
# Name: 1931, dtype: object ['11', '13', '2016']
# game_id      2016111308
# home_team           WAS
# game_date    11/13/2016
# Name: 1932, dtype: object ['11', '13', '2016']
# game_id      2016111309
# home_team            SD
# game_date    11/13/2016
# Name: 1933, dtype: object ['11', '13', '2016']
# game_id      2016111310
# home_team           ARI
# game_date    11/13/2016
# Name: 1934, dtype: object ['11', '13', '2016']
# game_id      2016111311
# home_team           PIT
# game_date    11/13/2016
# Name: 1935, dtype: object ['11', '13', '2016']
# game_id      2016111312
# home_team            NE
# game_date    11/13/2016
# Name: 1936, dtype: object ['11', '13', '2016']
# game_id      2016111400
# home_team           NYG
# game_date    11/14/2016
# Name: 1937, dtype: object ['11', '14', '2016']
# game_id      2016111700
# home_team           CAR
# game_date    11/17/2016
# Name: 1938, dtype: object ['11', '17', '2016']
# game_id      2016112000
# home_team           CIN
# game_date    11/20/2016
# Name: 1939, dtype: object ['11', '20', '2016']
# game_id      2016112001
# home_team           CLE
# game_date    11/20/2016
# Name: 1940, dtype: object ['11', '20', '2016']
# game_id      2016112002
# home_team           DAL
# game_date    11/20/2016
# Name: 1941, dtype: object ['11', '20', '2016']
# game_id      2016112003
# home_team           DET
# game_date    11/20/2016
# Name: 1942, dtype: object ['11', '20', '2016']
# game_id      2016112004
# home_team           IND
# game_date    11/20/2016
# Name: 1943, dtype: object ['11', '20', '2016']
# game_id      2016112005
# home_team            KC
# game_date    11/20/2016
# Name: 1944, dtype: object ['11', '20', '2016']
# game_id      2016112006
# home_team           MIN
# game_date    11/20/2016
# Name: 1945, dtype: object ['11', '20', '2016']
# game_id      2016112007
# home_team           NYG
# game_date    11/20/2016
# Name: 1946, dtype: object ['11', '20', '2016']
# game_id      2016112008
# home_team            LA
# game_date    11/20/2016
# Name: 1947, dtype: object ['11', '20', '2016']
# game_id      2016112009
# home_team            SF
# game_date    11/20/2016
# Name: 1948, dtype: object ['11', '20', '2016']
# game_id      2016112010
# home_team           SEA
# game_date    11/20/2016
# Name: 1949, dtype: object ['11', '20', '2016']
# game_id      2016112011
# home_team           WAS
# game_date    11/20/2016
# Name: 1950, dtype: object ['11', '20', '2016']
# game_id      2016112100
# home_team           OAK
# game_date    11/21/2016
# Name: 1951, dtype: object ['11', '21', '2016']
# game_id      2016112400
# home_team           DET
# game_date    11/24/2016
# Name: 1952, dtype: object ['11', '24', '2016']
# game_id      2016112401
# home_team           DAL
# game_date    11/24/2016
# Name: 1953, dtype: object ['11', '24', '2016']
# game_id      2016112402
# home_team           IND
# game_date    11/24/2016
# Name: 1954, dtype: object ['11', '24', '2016']
# game_id      2016112700
# home_team           ATL
# game_date    11/27/2016
# Name: 1955, dtype: object ['11', '27', '2016']
# game_id      2016112701
# home_team           BAL
# game_date    11/27/2016
# Name: 1956, dtype: object ['11', '27', '2016']
# game_id      2016112702
# home_team           BUF
# game_date    11/27/2016
# Name: 1957, dtype: object ['11', '27', '2016']
# game_id      2016112703
# home_team           CHI
# game_date    11/27/2016
# Name: 1958, dtype: object ['11', '27', '2016']
# game_id      2016112705
# home_team           HOU
# game_date    11/27/2016
# Name: 1959, dtype: object ['11', '27', '2016']
# game_id      2016112706
# home_team           MIA
# game_date    11/27/2016
# Name: 1960, dtype: object ['11', '27', '2016']
# game_id      2016112707
# home_team            NO
# game_date    11/27/2016
# Name: 1961, dtype: object ['11', '27', '2016']
# game_id      2016112708
# home_team            TB
# game_date    11/27/2016
# Name: 1962, dtype: object ['11', '27', '2016']
# game_id      2016112709
# home_team           DEN
# game_date    11/27/2016
# Name: 1963, dtype: object ['11', '27', '2016']
# game_id      2016112710
# home_team           OAK
# game_date    11/27/2016
# Name: 1964, dtype: object ['11', '27', '2016']
# game_id      2016112711
# home_team           NYJ
# game_date    11/27/2016
# Name: 1965, dtype: object ['11', '27', '2016']
# game_id      2016112800
# home_team           PHI
# game_date    11/28/2016
# Name: 1966, dtype: object ['11', '28', '2016']
# game_id      2016120100
# home_team           MIN
# game_date     12/1/2016
# Name: 1967, dtype: object ['12', '1', '2016']
# game_id      2016120400
# home_team           ATL
# game_date     12/4/2016
# Name: 1968, dtype: object ['12', '4', '2016']
# game_id      2016120401
# home_team           BAL
# game_date     12/4/2016
# Name: 1969, dtype: object ['12', '4', '2016']
# game_id      2016120402
# home_team           CHI
# game_date     12/4/2016
# Name: 1970, dtype: object ['12', '4', '2016']
# game_id      2016120403
# home_team           CIN
# game_date     12/4/2016
# Name: 1971, dtype: object ['12', '4', '2016']
# game_id      2016120404
# home_team            GB
# game_date     12/4/2016
# Name: 1972, dtype: object ['12', '4', '2016']
# game_id      2016120405
# home_team           JAX
# game_date     12/4/2016
# Name: 1973, dtype: object ['12', '4', '2016']
# game_id      2016120406
# home_team            NE
# game_date     12/4/2016
# Name: 1974, dtype: object ['12', '4', '2016']
# game_id      2016120407
# home_team            NO
# game_date     12/4/2016
# Name: 1975, dtype: object ['12', '4', '2016']
# game_id      2016120408
# home_team           OAK
# game_date     12/4/2016
# Name: 1976, dtype: object ['12', '4', '2016']
# game_id      2016120409
# home_team           ARI
# game_date     12/4/2016
# Name: 1977, dtype: object ['12', '4', '2016']
# game_id      2016120410
# home_team           PIT
# game_date     12/4/2016
# Name: 1978, dtype: object ['12', '4', '2016']
# game_id      2016120411
# home_team            SD
# game_date     12/4/2016
# Name: 1979, dtype: object ['12', '4', '2016']
# game_id      2016120412
# home_team           SEA
# game_date     12/4/2016
# Name: 1980, dtype: object ['12', '4', '2016']
# game_id      2016120500
# home_team           NYJ
# game_date     12/5/2016
# Name: 1981, dtype: object ['12', '5', '2016']
# game_id      2016120800
# home_team            KC
# game_date     12/8/2016
# Name: 1982, dtype: object ['12', '8', '2016']
# game_id      2016121100
# home_team           BUF
# game_date    12/11/2016
# Name: 1983, dtype: object ['12', '11', '2016']
# game_id      2016121101
# home_team           CAR
# game_date    12/11/2016
# Name: 1984, dtype: object ['12', '11', '2016']
# game_id      2016121102
# home_team           CLE
# game_date    12/11/2016
# Name: 1985, dtype: object ['12', '11', '2016']
# game_id      2016121103
# home_team           DET
# game_date    12/11/2016
# Name: 1986, dtype: object ['12', '11', '2016']
# game_id      2016121104
# home_team           IND
# game_date    12/11/2016
# Name: 1987, dtype: object ['12', '11', '2016']
# game_id      2016121105
# home_team           JAX
# game_date    12/11/2016
# Name: 1988, dtype: object ['12', '11', '2016']
# game_id      2016121106
# home_team           MIA
# game_date    12/11/2016
# Name: 1989, dtype: object ['12', '11', '2016']
# game_id      2016121107
# home_team           PHI
# game_date    12/11/2016
# Name: 1990, dtype: object ['12', '11', '2016']
# game_id      2016121108
# home_team            TB
# game_date    12/11/2016
# Name: 1991, dtype: object ['12', '11', '2016']
# game_id      2016121109
# home_team           TEN
# game_date    12/11/2016
# Name: 1992, dtype: object ['12', '11', '2016']
# game_id      2016121110
# home_team            SF
# game_date    12/11/2016
# Name: 1993, dtype: object ['12', '11', '2016']
# game_id      2016121111
# home_team            GB
# game_date    12/11/2016
# Name: 1994, dtype: object ['12', '11', '2016']
# game_id      2016121112
# home_team            LA
# game_date    12/11/2016
# Name: 1995, dtype: object ['12', '11', '2016']
# game_id      2016121113
# home_team           NYG
# game_date    12/11/2016
# Name: 1996, dtype: object ['12', '11', '2016']
# game_id      2016121200
# home_team            NE
# game_date    12/12/2016
# Name: 1997, dtype: object ['12', '12', '2016']
# game_id      2016121500
# home_team           SEA
# game_date    12/15/2016
# Name: 1998, dtype: object ['12', '15', '2016']
# game_id      2016121700
# home_team           NYJ
# game_date    12/17/2016
# Name: 1999, dtype: object ['12', '17', '2016']
# game_id      2016121800
# home_team           BAL
# game_date    12/18/2016
# Name: 2000, dtype: object ['12', '18', '2016']
# game_id      2016121801
# home_team           BUF
# game_date    12/18/2016
# Name: 2001, dtype: object ['12', '18', '2016']
# game_id      2016121802
# home_team           CHI
# game_date    12/18/2016
# Name: 2002, dtype: object ['12', '18', '2016']
# game_id      2016121803
# home_team           DAL
# game_date    12/18/2016
# Name: 2003, dtype: object ['12', '18', '2016']
# game_id      2016121804
# home_team           HOU
# game_date    12/18/2016
# Name: 2004, dtype: object ['12', '18', '2016']
# game_id      2016121805
# home_team            KC
# game_date    12/18/2016
# Name: 2005, dtype: object ['12', '18', '2016']
# game_id      2016121806
# home_team           MIN
# game_date    12/18/2016
# Name: 2006, dtype: object ['12', '18', '2016']
# game_id      2016121807
# home_team           NYG
# game_date    12/18/2016
# Name: 2007, dtype: object ['12', '18', '2016']
# game_id      2016121808
# home_team           ARI
# game_date    12/18/2016
# Name: 2008, dtype: object ['12', '18', '2016']
# game_id      2016121809
# home_team           ATL
# game_date    12/18/2016
# Name: 2009, dtype: object ['12', '18', '2016']
# game_id      2016121810
# home_team           DEN
# game_date    12/18/2016
# Name: 2010, dtype: object ['12', '18', '2016']
# game_id      2016121811
# home_team            SD
# game_date    12/18/2016
# Name: 2011, dtype: object ['12', '18', '2016']
# game_id      2016121812
# home_team           CIN
# game_date    12/18/2016
# Name: 2012, dtype: object ['12', '18', '2016']
# game_id      2016121900
# home_team           WAS
# game_date    12/19/2016
# Name: 2013, dtype: object ['12', '19', '2016']
# game_id      2016122200
# home_team           PHI
# game_date    12/22/2016
# Name: 2014, dtype: object ['12', '22', '2016']
# game_id      2016122400
# home_team           BUF
# game_date    12/24/2016
# Name: 2015, dtype: object ['12', '24', '2016']
# game_id      2016122401
# home_team           CAR
# game_date    12/24/2016
# Name: 2016, dtype: object ['12', '24', '2016']
# game_id      2016122402
# home_team           CHI
# game_date    12/24/2016
# Name: 2017, dtype: object ['12', '24', '2016']
# game_id      2016122403
# home_team           CLE
# game_date    12/24/2016
# Name: 2018, dtype: object ['12', '24', '2016']
# game_id      2016122404
# home_team            GB
# game_date    12/24/2016
# Name: 2019, dtype: object ['12', '24', '2016']
# game_id      2016122405
# home_team           JAX
# game_date    12/24/2016
# Name: 2020, dtype: object ['12', '24', '2016']
# game_id      2016122406
# home_team            NE
# game_date    12/24/2016
# Name: 2021, dtype: object ['12', '24', '2016']
# game_id      2016122407
# home_team            NO
# game_date    12/24/2016
# Name: 2022, dtype: object ['12', '24', '2016']
# game_id      2016122408
# home_team           OAK
# game_date    12/24/2016
# Name: 2023, dtype: object ['12', '24', '2016']
# game_id      2016122409
# home_team            LA
# game_date    12/24/2016
# Name: 2024, dtype: object ['12', '24', '2016']
# game_id      2016122410
# home_team           SEA
# game_date    12/24/2016
# Name: 2025, dtype: object ['12', '24', '2016']
# game_id      2016122411
# home_team           HOU
# game_date    12/24/2016
# Name: 2026, dtype: object ['12', '24', '2016']
# game_id      2016122500
# home_team           PIT
# game_date    12/25/2016
# Name: 2027, dtype: object ['12', '25', '2016']
# game_id      2016122501
# home_team            KC
# game_date    12/25/2016
# Name: 2028, dtype: object ['12', '25', '2016']
# game_id      2016122600
# home_team           DAL
# game_date    12/26/2016
# Name: 2029, dtype: object ['12', '26', '2016']
# game_id      2017010100
# home_team           ATL
# game_date      1/1/2017
# Name: 2030, dtype: object ['1', '1', '2017']
# game_id      2017010101
# home_team           CIN
# game_date      1/1/2017
# Name: 2031, dtype: object ['1', '1', '2017']
# game_id      2017010102
# home_team           DET
# game_date      1/1/2017
# Name: 2032, dtype: object ['1', '1', '2017']
# game_id      2017010103
# home_team           IND
# game_date      1/1/2017
# Name: 2033, dtype: object ['1', '1', '2017']
# game_id      2017010104
# home_team           MIA
# game_date      1/1/2017
# Name: 2034, dtype: object ['1', '1', '2017']
# game_id      2017010105
# home_team           MIN
# game_date      1/1/2017
# Name: 2035, dtype: object ['1', '1', '2017']
# game_id      2017010106
# home_team           NYJ
# game_date      1/1/2017
# Name: 2036, dtype: object ['1', '1', '2017']
# game_id      2017010107
# home_team           PHI
# game_date      1/1/2017
# Name: 2037, dtype: object ['1', '1', '2017']
# game_id      2017010108
# home_team           PIT
# game_date      1/1/2017
# Name: 2038, dtype: object ['1', '1', '2017']
# game_id      2017010109
# home_team            TB
# game_date      1/1/2017
# Name: 2039, dtype: object ['1', '1', '2017']
# game_id      2017010110
# home_team           TEN
# game_date      1/1/2017
# Name: 2040, dtype: object ['1', '1', '2017']
# game_id      2017010111
# home_team           WAS
# game_date      1/1/2017
# Name: 2041, dtype: object ['1', '1', '2017']
# game_id      2017010112
# home_team           DEN
# game_date      1/1/2017
# Name: 2042, dtype: object ['1', '1', '2017']
# game_id      2017010113
# home_team            LA
# game_date      1/1/2017
# Name: 2043, dtype: object ['1', '1', '2017']
# game_id      2017010114
# home_team            SD
# game_date      1/1/2017
# Name: 2044, dtype: object ['1', '1', '2017']
# game_id      2017010115
# home_team            SF
# game_date      1/1/2017
# Name: 2045, dtype: object ['1', '1', '2017']
# game_id      2017090700
# home_team            NE
# game_date    2017-09-07
# Name: 2046, dtype: object ['2017-09-07']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-57c32532859c> in <module>
#       4        order by pbp.game_id"
#       5 df_gameids = pd.read_sql_query(sql, kaggle_conn, index_col=None)
# ----> 6 df_gameids['idx'] = df_gameids.apply(lambda row: get_pbpindex(row),axis=1)
#       7 df_gameids.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6485                          args=args,
#    6486                          kwds=kwds)
# -> 6487         return op.get_result()
#    6488
#    6489     def applymap(self, func):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     149             return self.apply_raw()
#     150
# --> 151         return self.apply_standard()
#     152
#     153     def apply_empty_result(self):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     255
#     256         # compute the result using the series generator
# --> 257         self.apply_series_generator()
#     258
#     259         # wrap results
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     284             try:
#     285                 for i, v in enumerate(series_gen):
# --> 286                     results[i] = self.f(v)
#     287                     keys.append(v.name)
#     288             except Exception as e:
#
# <ipython-input-9-57c32532859c> in <lambda>(row)
#       4        order by pbp.game_id"
#       5 df_gameids = pd.read_sql_query(sql, kaggle_conn, index_col=None)
# ----> 6 df_gameids['idx'] = df_gameids.apply(lambda row: get_pbpindex(row),axis=1)
#       7 df_gameids.head()
#
# <ipython-input-8-32a8cc021364> in get_pbpindex(row)
#      54     comps = row['game_date'].split('/')
#      55     print(row,comps)
# ---> 56     date = comps[2]+'-'+comps[0]+'-'+comps[1]
#      57     idx = date+team_name
#      58     idx = row['game_date']+team_name
#
# IndexError: ('list index out of range', 'occurred at index 2046')

# %%
df.head()
# Out:
#               schedule_date  schedule_season schedule_week  schedule_playoff  \
# idx
# 2009-09-10PIT    09/10/2009             2009             1             False
# 2009-09-13ARI    09/13/2009             2009             1             False
# 2009-09-13ATL    09/13/2009             2009             1             False
# 2009-09-13BAL    09/13/2009             2009             1             False
# 2009-09-13CAR    09/13/2009             2009             1             False
#
#                          team_home  score_home  score_away  \
# idx
# 2009-09-10PIT  Pittsburgh Steelers          13          10
# 2009-09-13ARI    Arizona Cardinals          16          20
# 2009-09-13ATL      Atlanta Falcons          19           7
# 2009-09-13BAL     Baltimore Ravens          38          24
# 2009-09-13CAR    Carolina Panthers          10          38
#
#                          team_away team_favorite_id  spread_favorite  \
# idx
# 2009-09-10PIT     Tennessee Titans              PIT             -6.5
# 2009-09-13ARI  San Francisco 49ers              ARI             -4.5
# 2009-09-13ATL       Miami Dolphins              ATL             -4.0
# 2009-09-13BAL   Kansas City Chiefs              BAL            -13.0
# 2009-09-13CAR  Philadelphia Eagles              PHI             -2.5
#
#               over_under_line                        stadium  stadium_neutral  \
# idx
# 2009-09-10PIT              35                    Heinz Field            False
# 2009-09-13ARI              45  University of Phoenix Stadium            False
# 2009-09-13ATL            44.5                   Georgia Dome            False
# 2009-09-13BAL            36.5               M&T Bank Stadium            False
# 2009-09-13CAR            43.5        Bank of America Stadium            False
#
#                weather_temperature  weather_wind_mph weather_humidity  \
# idx
# 2009-09-10PIT                 67.0               9.0               64
# 2009-09-13ARI                 72.0               0.0              NaN
# 2009-09-13ATL                 72.0               0.0              NaN
# 2009-09-13BAL                 69.0               7.0               74
# 2009-09-13CAR                 77.0               7.0               59
#
#               weather_detail  home_favorite  spread_result  OU_result
# idx
# 2009-09-10PIT            NaN              1             -1         -1
# 2009-09-13ARI           DOME              1             -1         -1
# 2009-09-13ATL           DOME              1              1         -1
# 2009-09-13BAL            NaN              1              1          1
# 2009-09-13CAR            NaN              0              1          1
