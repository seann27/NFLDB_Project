# %%
import pandas as pd
import numpy as np
import re
from scrapers.GeneralScraper import Scraper
from NFL_RefMaps import TableColumns,TeamDictionary

# %%
link = 'https://www.fantasypros.com/nfl/projections/dst.php?week=1&scoring=HALF'
page_soup = Scraper(link).page_soup

# %%
data = page_soup.find("tbody")

# %%
table = 'dst_projections'
metrics = [TableColumns().fantasy_pros[table]]
players = data.findAll("tr",{"class":re.compile(r'mpb-player-')})

# %%
for player in players:
    stats = player.findAll("td")
    name = stats[0].a.text
#     team = stats[0].text.strip().split()[-1]
    team = TeamDictionary().nfl_api[name]
    a = stats[0].findAll("a")
    pid = a[1].get('class')[1]
    mets = np.array([pid,name,team])
    for stat in stats[1:]:
        mets = np.append(mets,stat.text)
    print(len(mets))
    print(mets)
    metrics.append(mets)
df = np.vstack(metrics)
pd.DataFrame(data=df[1:,1:],index=df[1:,0],columns=df[0,1:])
# Out:
# 12
# ['fp-id-8020' 'Baltimore Ravens' 'BAL' '2.6' '1.2' '0.6' '0.9' '0.2' '0.0'
#  '17.2' '290.2' '8.4']
# 12
# ['fp-id-8210' 'New York Jets' 'NYJ' '2.8' '1.1' '0.6' '0.9' '0.2' '0.0'
#  '19.0' '320.5' '8.2']
# 12
# ['fp-id-8070' 'Cleveland Browns' 'CLE' '2.7' '0.9' '0.7' '1.4' '0.2' '0.0'
#  '19.3' '309.2' '8.0']
# 12
# ['fp-id-8080' 'Dallas Cowboys' 'DAL' '2.9' '0.9' '0.7' '1.2' '0.2' '0.0'
#  '17.8' '317.9' '7.9']
# 12
# ['fp-id-8260' 'Seattle Seahawks' 'SEA' '2.7' '1.0' '0.6' '1.0' '0.2' '0.0'
#  '17.7' '316.1' '7.9']
# 12
# ['fp-id-8190' 'New Orleans Saints' 'NO' '3.5' '0.9' '0.7' '1.1' '0.2'
#  '0.0' '21.2' '350.8' '7.8']
# 12
# ['fp-id-8230' 'Philadelphia Eagles' 'PHI' '2.5' '1.0' '0.6' '0.9' '0.2'
#  '0.0' '17.2' '312.3' '7.7']
# 12
# ['fp-id-8100' 'Detroit Lions' 'DET' '3.2' '0.9' '0.7' '1.0' '0.2' '0.0'
#  '20.6' '322.6' '7.5']
# 12
# ['fp-id-8270' 'San Francisco 49ers' 'SF' '2.9' '1.1' '0.7' '1.0' '0.2'
#  '0.0' '24.6' '366.1' '7.5']
# 12
# ['fp-id-8250' 'Los Angeles Chargers' 'LAC' '2.6' '0.9' '0.6' '0.8' '0.1'
#  '0.0' '17.7' '326.7' '7.3']
# 12
# ['fp-id-8290' 'Tampa Bay Buccaneers' 'TB' '2.9' '0.9' '0.7' '1.2' '0.2'
#  '0.0' '24.4' '387.8' '7.3']
# 12
# ['fp-id-8090' 'Denver Broncos' 'DEN' '3.1' '0.7' '0.9' '1.4' '0.2' '0.0'
#  '20.1' '343.9' '7.3']
# 12
# ['fp-id-8150' 'Kansas City Chiefs' 'KC' '3.0' '0.8' '0.8' '1.4' '0.2'
#  '0.1' '22.0' '340.5' '7.2']
# 12
# ['fp-id-8030' 'Buffalo Bills' 'BUF' '2.5' '1.1' '0.7' '1.1' '0.2' '0.0'
#  '21.4' '297.7' '7.2']
# 12
# ['fp-id-8180' 'New England Patriots' 'NE' '1.8' '1.1' '0.6' '1.1' '0.1'
#  '0.1' '19.9' '394.6' '7.0']
# 12
# ['fp-id-8280' 'Los Angeles Rams' 'LA' '2.6' '1.0' '0.6' '0.9' '0.2' '0.0'
#  '22.6' '362.6' '6.9']
# 12
# ['fp-id-8110' 'Green Bay Packers' 'GB' '2.6' '0.9' '0.7' '0.9' '0.1' '0.0'
#  '23.5' '350.0' '6.6']
# 12
# ['fp-id-8050' 'Chicago Bears' 'CHI' '3.4' '0.6' '0.6' '0.9' '0.1' '0.0'
#  '20.5' '329.2' '6.6']
# 12
# ['fp-id-8170' 'Minnesota Vikings' 'MIN' '3.0' '0.7' '0.7' '0.9' '0.1'
#  '0.0' '20.1' '339.6' '6.6']
# 12
# ['fp-id-8000' 'Arizona Cardinals' 'ARI' '3.0' '0.8' '0.6' '1.1' '0.1'
#  '0.0' '23.4' '341.4' '6.5']
# 12
# ['fp-id-8160' 'Miami Dolphins' 'MIA' '2.2' '0.9' '0.7' '0.9' '0.2' '0.0'
#  '23.9' '376.9' '6.3']
# 12
# ['fp-id-8010' 'Atlanta Falcons' 'ATL' '2.4' '0.8' '0.6' '1.0' '0.1' '0.0'
#  '23.5' '351.2' '6.2']
# 12
# ['fp-id-8310' 'Washington Redskins' 'WAS' '2.5' '0.8' '0.7' '1.2' '0.1'
#  '0.0' '26.2' '363.9' '6.2']
# 12
# ['fp-id-8300' 'Tennessee Titans' 'TEN' '2.5' '0.9' '0.6' '0.9' '0.1' '0.0'
#  '23.2' '369.1' '6.2']
# 12
# ['fp-id-8200' 'New York Giants' 'NYG' '2.6' '0.8' '0.6' '0.8' '0.1' '0.0'
#  '24.8' '349.4' '6.0']
# 12
# ['fp-id-8130' 'Indianapolis Colts' 'IND' '2.4' '0.8' '0.7' '1.0' '0.1'
#  '0.0' '24.3' '361.8' '6.0']
# 12
# ['fp-id-8040' 'Carolina Panthers' 'CAR' '2.2' '0.9' '0.6' '1.1' '0.1'
#  '0.1' '25.6' '403.3' '6.0']
# 12
# ['fp-id-8140' 'Jacksonville Jaguars' 'JAX' '2.3' '0.8' '0.5' '0.7' '0.1'
#  '0.0' '24.5' '361.3' '5.8']
# 12
# ['fp-id-8060' 'Cincinnati Bengals' 'CIN' '2.8' '0.6' '0.5' '0.4' '0.1'
#  '0.0' '25.5' '360.5' '5.7']
# 12
# ['fp-id-8220' 'Oakland Raiders' 'OAK' '1.7' '1.0' '0.5' '0.9' '0.1' '0.0'
#  '22.3' '372.7' '5.6']
# 12
# ['fp-id-8120' 'Houston Texans' 'HOU' '2.0' '0.7' '0.7' '1.1' '0.1' '0.0'
#  '26.5' '365.4' '5.5']
# 12
# ['fp-id-8240' 'Pittsburgh Steelers' 'PIT' '2.1' '0.6' '0.5' '0.7' '0.1'
#  '0.0' '25.0' '367.8' '4.9']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-e68e26071253> in <module>
#      12     print(mets)
#      13     metrics.append(mets)
# ---> 14 df = np.vstack(metrics)
#      15 pd.DataFrame(data=df[1:,1:],index=df[1:,0],columns=df[0,1:])
#
# <__array_function__ internals> in vstack(*args, **kwargs)
#
# c:\users\skbla\appdata\local\programs\python\python36-32\lib\site-packages\numpy\core\shape_base.py in vstack(tup)
#     280     if not isinstance(arrs, list):
#     281         arrs = [arrs]
# --> 282     return _nx.concatenate(arrs, 0)
#     283
#     284
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 1, the array at index 0 has size 13 and the array at index 1 has size 12

# %%
import pandas as pd
import numpy as np
import re
from scrapers.GeneralScraper import Scraper
from NFL_RefMaps import TableColumns,TeamDictionary

class LoadProjections():

    def __init__(self,week):

        self.week = week
        self.projections = self.get_all_projections()

    def get_projections(self,pos):
        link = "https://www.fantasypros.com/nfl/projections/"+pos+".php?week="+str(self.week)+"&scoring=HALF"
        print(link)
        page_soup = Scraper(link).get_soup()
        data = page_soup.find("tbody")

        table = pos+'_projections'
        metrics = [TableColumns().fantasy_pros[table]]
        players = data.findAll("tr",{"class":re.compile(r'mpb-player-')})
        for player in players:
            stats = player.findAll("td")
            name = stats[0].a.text
            print(name)
            team = 'n/a'
            if pos == 'dst':
                team = TeamDictionary().nfl_api[name]
            else:
                print(stats[0].text)
                ts = stats[0].text.strip().split()
                if len(ts) == 0:
                    print("Error detected, skipping this row")
                    break
                print(ts)
                print(len(ts))
                team = stats[0].text.strip().split()[-1]
            a = stats[0].findAll("a")
            pid = a[1].get('class')[1]
            mets = np.array([pid,name,team,self.week])
            for stat in stats[1:]:
                mets = np.append(mets,stat.text)
            metrics.append(mets)
        df = np.vstack(metrics)

        return pd.DataFrame(data=df[1:,1:],index=df[1:,0],columns=df[0,1:])

    def get_all_projections(self):
        projections = {
            'qb':'',
            'rb':'',
            'wr':'',
            'te':'',
            'dst':'',
            'k':''
        }
        for key,val in projections.items():
            projections[key] = self.get_projections(key)

        return projections

# %%
proj = LoadProjections(week=1)
# Out:
# https://www.fantasypros.com/nfl/projections/qb.php?week=1&scoring=HALF
# Patrick Mahomes
# Patrick Mahomes KC
# ['Patrick', 'Mahomes', 'KC']
# 3
# Deshaun Watson
# Deshaun Watson HOU
# ['Deshaun', 'Watson', 'HOU']
# 3
# Drew Brees
# Drew Brees NO
# ['Drew', 'Brees', 'NO']
# 3
# Lamar Jackson
# Lamar Jackson BAL
# ['Lamar', 'Jackson', 'BAL']
# 3
# Jameis Winston
# Jameis Winston TB
# ['Jameis', 'Winston', 'TB']
# 3
# Dak Prescott
# Dak Prescott DAL
# ['Dak', 'Prescott', 'DAL']
# 3
# Russell Wilson
# Russell Wilson SEA
# ['Russell', 'Wilson', 'SEA']
# 3
# Cam Newton
# Cam Newton CAR
# ['Cam', 'Newton', 'CAR']
# 3
# Carson Wentz
# Carson Wentz PHI
# ['Carson', 'Wentz', 'PHI']
# 3
# Aaron Rodgers
# Aaron Rodgers GB
# ['Aaron', 'Rodgers', 'GB']
# 3
# Baker Mayfield
# Baker Mayfield CLE
# ['Baker', 'Mayfield', 'CLE']
# 3
# Jared Goff
# Jared Goff LAR
# ['Jared', 'Goff', 'LAR']
# 3
# Mitch Trubisky
# Mitch Trubisky CHI
# ['Mitch', 'Trubisky', 'CHI']
# 3
# Tom Brady
# Tom Brady NE
# ['Tom', 'Brady', 'NE']
# 3
# Ben Roethlisberger
# Ben Roethlisberger PIT
# ['Ben', 'Roethlisberger', 'PIT']
# 3
# Kyler Murray
# Kyler Murray ARI
# ['Kyler', 'Murray', 'ARI']
# 3
# Matt Ryan
# Matt Ryan ATL
# ['Matt', 'Ryan', 'ATL']
# 3
# Kirk Cousins
# Kirk Cousins MIN
# ['Kirk', 'Cousins', 'MIN']
# 3
# Philip Rivers
# Philip Rivers LAC
# ['Philip', 'Rivers', 'LAC']
# 3
# Jimmy Garoppolo
# Jimmy Garoppolo SF
# ['Jimmy', 'Garoppolo', 'SF']
# 3
# Josh Allen
# Josh Allen BUF
# ['Josh', 'Allen', 'BUF']
# 3
# Matthew Stafford
# Matthew Stafford DET
# ['Matthew', 'Stafford', 'DET']
# 3
# Nick Foles
# Nick Foles JAC
# ['Nick', 'Foles', 'JAC']
# 3
# Derek Carr
# Derek Carr OAK
# ['Derek', 'Carr', 'OAK']
# 3
# Joe Flacco
# Joe Flacco DEN
# ['Joe', 'Flacco', 'DEN']
# 3
# Sam Darnold
# Sam Darnold NYJ
# ['Sam', 'Darnold', 'NYJ']
# 3
# Jacoby Brissett
# Jacoby Brissett IND
# ['Jacoby', 'Brissett', 'IND']
# 3
# Marcus Mariota
# Marcus Mariota TEN
# ['Marcus', 'Mariota', 'TEN']
# 3
# Andy Dalton
# Andy Dalton CIN
# ['Andy', 'Dalton', 'CIN']
# 3
# Eli Manning
# Eli Manning NYG
# ['Eli', 'Manning', 'NYG']
# 3
# Ryan Fitzpatrick
# Ryan Fitzpatrick MIA
# ['Ryan', 'Fitzpatrick', 'MIA']
# 3
# Case Keenum
# Case Keenum WAS
# ['Case', 'Keenum', 'WAS']
# 3
# Taysom Hill
# Taysom Hill NO
# ['Taysom', 'Hill', 'NO']
# 3
# Daniel Jones
# Daniel Jones NYG
# ['Daniel', 'Jones', 'NYG']
# 3
# DeShone Kizer
# DeShone Kizer OAK
# ['DeShone', 'Kizer', 'OAK']
# 3
# Josh Rosen
# Josh Rosen MIA
# ['Josh', 'Rosen', 'MIA']
# 3
# Josh McCown
# Josh McCown PHI
# ['Josh', 'McCown', 'PHI']
# 3
# Dwayne Haskins
# Dwayne Haskins WAS
# ['Dwayne', 'Haskins', 'WAS']
# 3
# Drew Lock
# Drew Lock DEN
# ['Drew', 'Lock', 'DEN']
# 3
# Blake Bortles
# Blake Bortles LAR
# ['Blake', 'Bortles', 'LAR']
# 3
# Teddy Bridgewater
# Teddy Bridgewater NO
# ['Teddy', 'Bridgewater', 'NO']
# 3
# Robert Griffin
# Robert Griffin BAL
# ['Robert', 'Griffin', 'BAL']
# 3
# Nick Mullens
# Nick Mullens SF
# ['Nick', 'Mullens', 'SF']
# 3
# Geno Smith
# Geno Smith SEA
# ['Geno', 'Smith', 'SEA']
# 3
# Tyrod Taylor
# Tyrod Taylor LAC
# ['Tyrod', 'Taylor', 'LAC']
# 3
# Matt Moore
# Matt Moore KC
# ['Matt', 'Moore', 'KC']
# 3
# Brian Hoyer
# Brian Hoyer IND
# ['Brian', 'Hoyer', 'IND']
# 3
# Drew Stanton
# Drew Stanton CLE
# ['Drew', 'Stanton', 'CLE']
# 3
# Brett Hundley
# Brett Hundley ARI
# ['Brett', 'Hundley', 'ARI']
# 3
# Joshua Dobbs
# Joshua Dobbs JAC
# ['Joshua', 'Dobbs', 'JAC']
# 3
# Jake Rudock
# Jake Rudock MIA
# ['Jake', 'Rudock', 'MIA']
# 3
# Chase Daniel
# Chase Daniel CHI
# ['Chase', 'Daniel', 'CHI']
# 3
# Ryan Tannehill
# Ryan Tannehill TEN
# ['Ryan', 'Tannehill', 'TEN']
# 3
# Matt Barkley
# Matt Barkley BUF
# ['Matt', 'Barkley', 'BUF']
# 3
# Matt Schaub
# Matt Schaub ATL
# ['Matt', 'Schaub', 'ATL']
# 3
# Mike Glennon
# Mike Glennon OAK
# ['Mike', 'Glennon', 'OAK']
# 3
# AJ McCarron
# AJ McCarron HOU
# ['AJ', 'McCarron', 'HOU']
# 3
# Trevor Siemian
# Trevor Siemian NYJ
# ['Trevor', 'Siemian', 'NYJ']
# 3
# Jarrett Stidham
# Jarrett Stidham NE
# ['Jarrett', 'Stidham', 'NE']
# 3
# Kyle Sloter
# Kyle Sloter ARI
# ['Kyle', 'Sloter', 'ARI']
# 3
# Danny Etling
# Danny Etling ATL
# ['Danny', 'Etling', 'ATL']
# 3
# Mason Rudolph
# Mason Rudolph PIT
# ['Mason', 'Rudolph', 'PIT']
# 3
# Gardner Minshew
# Gardner Minshew JAC
# ['Gardner', 'Minshew', 'JAC']
# 3
# Sean Mannion
# Sean Mannion MIN
# ['Sean', 'Mannion', 'MIN']
# 3
# Tim Boyle
# Tim Boyle GB
# ['Tim', 'Boyle', 'GB']
# 3
# Ryan Finley
# Ryan Finley CIN
# ['Ryan', 'Finley', 'CIN']
# 3
# https://www.fantasypros.com/nfl/projections/rb.php?week=1&scoring=HALF
# Christian McCaffrey
# Christian McCaffrey CAR
# ['Christian', 'McCaffrey', 'CAR']
# 3
# Alvin Kamara
# Alvin Kamara NO
# ['Alvin', 'Kamara', 'NO']
# 3
# Saquon Barkley
# Saquon Barkley NYG
# ['Saquon', 'Barkley', 'NYG']
# 3
# Dalvin Cook
# Dalvin Cook MIN
# ['Dalvin', 'Cook', 'MIN']
# 3
# Nick Chubb
# Nick Chubb CLE
# ['Nick', 'Chubb', 'CLE']
# 3
# Leonard Fournette
# Leonard Fournette JAC
# ['Leonard', 'Fournette', 'JAC']
# 3
# David Johnson
# David Johnson ARI
# ['David', 'Johnson', 'ARI']
# 3
# Chris Carson
# Chris Carson SEA
# ['Chris', 'Carson', 'SEA']
# 3
# Kerryon Johnson
# Kerryon Johnson DET
# ['Kerryon', 'Johnson', 'DET']
# 3
# Le'Veon Bell
# Le'Veon Bell NYJ
# ["Le'Veon", 'Bell', 'NYJ']
# 3
# James Conner
# James Conner PIT
# ['James', 'Conner', 'PIT']
# 3
# Ezekiel Elliott
# Ezekiel Elliott DAL
# ['Ezekiel', 'Elliott', 'DAL']
# 3
# Todd Gurley
# Todd Gurley LAR
# ['Todd', 'Gurley', 'LAR']
# 3
# Joe Mixon
# Joe Mixon CIN
# ['Joe', 'Mixon', 'CIN']
# 3
# Austin Ekeler
# Austin Ekeler LAC
# ['Austin', 'Ekeler', 'LAC']
# 3
# Josh Jacobs
# Josh Jacobs OAK
# ['Josh', 'Jacobs', 'OAK']
# 3
# Devonta Freeman
# Devonta Freeman ATL
# ['Devonta', 'Freeman', 'ATL']
# 3
# Phillip Lindsay
# Phillip Lindsay DEN
# ['Phillip', 'Lindsay', 'DEN']
# 3
# Mark Ingram
# Mark Ingram BAL
# ['Mark', 'Ingram', 'BAL']
# 3
# Aaron Jones
# Aaron Jones GB
# ['Aaron', 'Jones', 'GB']
# 3
# Derrick Henry
# Derrick Henry TEN
# ['Derrick', 'Henry', 'TEN']
# 3
# Sony Michel
# Sony Michel NE
# ['Sony', 'Michel', 'NE']
# 3
# Damien Williams
# Damien Williams KC
# ['Damien', 'Williams', 'KC']
# 3
# David Montgomery
# David Montgomery CHI
# ['David', 'Montgomery', 'CHI']
# 3
# Marlon Mack
# Marlon Mack IND
# ['Marlon', 'Mack', 'IND']
# 3
# Duke Johnson
# Duke Johnson HOU
# ['Duke', 'Johnson', 'HOU']
# 3
# Matt Breida
# Matt Breida SF
# ['Matt', 'Breida', 'SF']
# 3
# Tevin Coleman
# Tevin Coleman SF
# ['Tevin', 'Coleman', 'SF']
# 3
# Derrius Guice
# Derrius Guice WAS
# ['Derrius', 'Guice', 'WAS']
# 3
# James White
# James White NE
# ['James', 'White', 'NE']
# 3
# Tarik Cohen
# Tarik Cohen CHI
# ['Tarik', 'Cohen', 'CHI']
# 3
# Jordan Howard
# Jordan Howard PHI
# ['Jordan', 'Howard', 'PHI']
# 3
# Kenyan Drake
# Kenyan Drake ARI
# ['Kenyan', 'Drake', 'ARI']
# 3
# Miles Sanders
# Miles Sanders PHI
# ['Miles', 'Sanders', 'PHI']
# 3
# Justin Jackson
# Justin Jackson LAC
# ['Justin', 'Jackson', 'LAC']
# 3
# Devin Singletary
# Devin Singletary BUF
# ['Devin', 'Singletary', 'BUF']
# 3
# Tony Pollard
# Tony Pollard DAL
# ['Tony', 'Pollard', 'DAL']
# 3
# Rashaad Penny
# Rashaad Penny SEA
# ['Rashaad', 'Penny', 'SEA']
# 3
# Royce Freeman
# Royce Freeman DEN
# ['Royce', 'Freeman', 'DEN']
# 3
# Latavius Murray
# Latavius Murray NO
# ['Latavius', 'Murray', 'NO']
# 3
# Dion Lewis
# Dion Lewis TEN
# ['Dion', 'Lewis', 'TEN']
# 3
# Peyton Barber
# Peyton Barber TB
# ['Peyton', 'Barber', 'TB']
# 3
# Chris Thompson
# Chris Thompson WAS
# ['Chris', 'Thompson', 'WAS']
# 3
# Jalen Richard
# Jalen Richard OAK
# ['Jalen', 'Richard', 'OAK']
# 3
# Frank Gore
# Frank Gore BUF
# ['Frank', 'Gore', 'BUF']
# 3
# Darrell Henderson
# Darrell Henderson LAR
# ['Darrell', 'Henderson', 'LAR']
# 3
# LeSean McCoy
# LeSean McCoy KC
# ['LeSean', 'McCoy', 'KC']
# 3
# Justice Hill
# Justice Hill BAL
# ['Justice', 'Hill', 'BAL']
# 3
# Kalen Ballage
# Kalen Ballage MIA
# ['Kalen', 'Ballage', 'MIA']
# 3
# Nyheim Hines
# Nyheim Hines IND
# ['Nyheim', 'Hines', 'IND']
# 3
# Ronald Jones II
# Ronald Jones II TB
# ['Ronald', 'Jones', 'II', 'TB']
# 4
# Giovani Bernard
# Giovani Bernard CIN
# ['Giovani', 'Bernard', 'CIN']
# 3
# Jaylen Samuels
# Jaylen Samuels PIT
# ['Jaylen', 'Samuels', 'PIT']
# 3
# Ty Montgomery
# Ty Montgomery NYJ
# ['Ty', 'Montgomery', 'NYJ']
# 3
# Ito Smith
# Ito Smith ATL
# ['Ito', 'Smith', 'ATL']
# 3
# Alexander Mattison
# Alexander Mattison MIN
# ['Alexander', 'Mattison', 'MIN']
# 3
# Ryquell Armstead
# Ryquell Armstead JAC
# ['Ryquell', 'Armstead', 'JAC']
# 3
# T.J. Yeldon
# T.J. Yeldon BUF
# ['T.J.', 'Yeldon', 'BUF']
# 3
# Carlos Hyde
# Carlos Hyde HOU
# ['Carlos', 'Hyde', 'HOU']
# 3
# Mike Davis
# Mike Davis CHI
# ['Mike', 'Davis', 'CHI']
# 3
# Dontrell Hilliard
# Dontrell Hilliard CLE
# ['Dontrell', 'Hilliard', 'CLE']
# 3
# Jamaal Williams
# Jamaal Williams GB
# ['Jamaal', 'Williams', 'GB']
# 3
# Darren Sproles
# Darren Sproles PHI
# ['Darren', 'Sproles', 'PHI']
# 3
# Gus Edwards
# Gus Edwards BAL
# ['Gus', 'Edwards', 'BAL']
# 3
# Darwin Thompson
# Darwin Thompson KC
# ['Darwin', 'Thompson', 'KC']
# 3
# Rex Burkhead
# Rex Burkhead NE
# ['Rex', 'Burkhead', 'NE']
# 3
# Malcolm Brown
# Malcolm Brown LAR
# ['Malcolm', 'Brown', 'LAR']
# 3
# Chase Edmonds
# Chase Edmonds ARI
# ['Chase', 'Edmonds', 'ARI']
# 3
# Reggie Bonnafon
# Reggie Bonnafon CAR
# ['Reggie', 'Bonnafon', 'CAR']
# 3
# Corey Clement
# Corey Clement PHI
# ['Corey', 'Clement', 'PHI']
# 3
# Wayne Gallman
# Wayne Gallman NYG
# ['Wayne', 'Gallman', 'NYG']
# 3
# Kyle Juszczyk
# Kyle Juszczyk SF
# ['Kyle', 'Juszczyk', 'SF']
# 3
# Devontae Booker
# Devontae Booker DEN
# ['Devontae', 'Booker', 'DEN']
# 3
# Ty Johnson
# Ty Johnson DET
# ['Ty', 'Johnson', 'DET']
# 3
# Dare Ogunbowale
# Dare Ogunbowale TB
# ['Dare', 'Ogunbowale', 'TB']
# 3
# Jordan Wilkins
# Jordan Wilkins IND
# ['Jordan', 'Wilkins', 'IND']
# 3
# DeAndre Washington
# DeAndre Washington OAK
# ['DeAndre', 'Washington', 'OAK']
# 3
# Wendell Smallwood
# Wendell Smallwood WAS
# ['Wendell', 'Smallwood', 'WAS']
# 3
# Travis Homer
# Travis Homer SEA
# ['Travis', 'Homer', 'SEA']
# 3
# Benny Snell Jr.
# Benny Snell Jr. PIT
# ['Benny', 'Snell', 'Jr.', 'PIT']
# 4
# Brian Hill
# Brian Hill ATL
# ['Brian', 'Hill', 'ATL']
# 3
# Paul Perkins
# Paul Perkins DET
# ['Paul', 'Perkins', 'DET']
# 3
# J.D. McKissic
# J.D. McKissic DET
# ['J.D.', 'McKissic', 'DET']
# 3
# Raheem Mostert
# Raheem Mostert SF
# ['Raheem', 'Mostert', 'SF']
# 3
# Troymaine Pope
# Troymaine Pope LAC
# ['Troymaine', 'Pope', 'LAC']
# 3
# Jordan Scarlett
# Jordan Scarlett CAR
# ['Jordan', 'Scarlett', 'CAR']
# 3
# D'Ernest Johnson
# D'Ernest Johnson CLE
# ["D'Ernest", 'Johnson', 'CLE']
# 3
# C.J. Prosise
# C.J. Prosise SEA
# ['C.J.', 'Prosise', 'SEA']
# 3
# Josh Adams
# Josh Adams NYJ
# ['Josh', 'Adams', 'NYJ']
# 3
# Brandon Bolden
# Brandon Bolden NE
# ['Brandon', 'Bolden', 'NE']
# 3
# Trenton Cannon
# Trenton Cannon NYJ
# ['Trenton', 'Cannon', 'NYJ']
# 3
# Mike Boone
# Mike Boone MIN
# ['Mike', 'Boone', 'MIN']
# 3
# Ameer Abdullah
# Ameer Abdullah MIN
# ['Ameer', 'Abdullah', 'MIN']
# 3
# Tyler Ervin
# Tyler Ervin JAC
# ['Tyler', 'Ervin', 'JAC']
# 3
# Buddy Howell
# Buddy Howell HOU
# ['Buddy', 'Howell', 'HOU']
# 3
# T.J. Logan
# T.J. Logan TB
# ['T.J.', 'Logan', 'TB']
# 3
# Devine Ozigbo
# Devine Ozigbo JAC
# ['Devine', 'Ozigbo', 'JAC']
# 3
# David Fluellen
# David Fluellen TEN
# ['David', 'Fluellen', 'TEN']
# 3
# Mark Walton
# Mark Walton MIA
# ['Mark', 'Walton', 'MIA']
# 3
# Darrel Williams
# Darrel Williams KC
# ['Darrel', 'Williams', 'KC']
# 3
# James Develin
# James Develin NE
# ['James', 'Develin', 'NE']
# 3
# Anthony Sherman
# Anthony Sherman KC
# ['Anthony', 'Sherman', 'KC']
# 3
# Taiwan Jones
# Taiwan Jones HOU
# ['Taiwan', 'Jones', 'HOU']
# 3
# CJ Ham
# CJ Ham MIN
# ['CJ', 'Ham', 'MIN']
# 3
# Elijhaa Penny
# Elijhaa Penny NYG
# ['Elijhaa', 'Penny', 'NYG']
# 3
# Zach Line
# Zach Line NO
# ['Zach', 'Line', 'NO']
# 3
# D.J. Foster
# D.J. Foster ARI
# ['D.J.', 'Foster', 'ARI']
# 3
# Chandler Cox
# Chandler Cox MIA
# ['Chandler', 'Cox', 'MIA']
# 3
# Samaje Perine
# Samaje Perine CIN
# ['Samaje', 'Perine', 'CIN']
# 3
# Kenjon Barner
# Kenjon Barner ATL
# ['Kenjon', 'Barner', 'ATL']
# 3
# Patrick DiMarco
# Patrick DiMarco BUF
# ['Patrick', 'DiMarco', 'BUF']
# 3
# Dwayne Washington
# Dwayne Washington NO
# ['Dwayne', 'Washington', 'NO']
# 3
# Alex Armah
# Alex Armah CAR
# ['Alex', 'Armah', 'CAR']
# 3
# Jamize Olawale
# Jamize Olawale DAL
# ['Jamize', 'Olawale', 'DAL']
# 3
# Roosevelt Nix
# Roosevelt Nix PIT
# ['Roosevelt', 'Nix', 'PIT']
# 3
# Derek Watt
# Derek Watt LAC
# ['Derek', 'Watt', 'LAC']
# 3
# Nick Bawden
# Nick Bawden DET
# ['Nick', 'Bawden', 'DET']
# 3
# Keith Smith
# Keith Smith ATL
# ['Keith', 'Smith', 'ATL']
# 3
# Tremon Smith
# Tremon Smith GB
# ['Tremon', 'Smith', 'GB']
# 3
# De'Lance Turner
# De'Lance Turner BAL
# ["De'Lance", 'Turner', 'BAL']
# 3
# Shaun Wilson
# Shaun Wilson WAS
# ['Shaun', 'Wilson', 'WAS']
# 3
# Nick Bellore
# Nick Bellore SEA
# ['Nick', 'Bellore', 'SEA']
# 3
# Alec Ingold
# Alec Ingold OAK
# ['Alec', 'Ingold', 'OAK']
# 3
# Michael Burton
# Michael Burton WAS
# ['Michael', 'Burton', 'WAS']
# 3
# Garrett Griffin
# Garrett Griffin NO
# ['Garrett', 'Griffin', 'NO']
# 3
# Cullen Gillaspia
# Cullen Gillaspia HOU
# ['Cullen', 'Gillaspia', 'HOU']
# 3
# Patrick Ricard
# Patrick Ricard BAL
# ['Patrick', 'Ricard', 'BAL']
# 3
# Dan Vitale
# Dan Vitale GB
# ['Dan', 'Vitale', 'GB']
# 3
# Senorise Perry
# Senorise Perry BUF
# ['Senorise', 'Perry', 'BUF']
# 3
# Justin Davis
# Justin Davis ARI
# ['Justin', 'Davis', 'ARI']
# 3
# Cethan Carter
# Cethan Carter CIN
# ['Cethan', 'Carter', 'CIN']
# 3
# Elijah Holyfield
# Elijah Holyfield CAR
# ['Elijah', 'Holyfield', 'CAR']
# 3
#
#
# Error detected, skipping this row
# https://www.fantasypros.com/nfl/projections/wr.php?week=1&scoring=HALF
# DeAndre Hopkins
# DeAndre Hopkins HOU
# ['DeAndre', 'Hopkins', 'HOU']
# 3
# Davante Adams
# Davante Adams GB
# ['Davante', 'Adams', 'GB']
# 3
# Michael Thomas
# Michael Thomas NO
# ['Michael', 'Thomas', 'NO']
# 3
# Odell Beckham Jr.
# Odell Beckham Jr. CLE
# ['Odell', 'Beckham', 'Jr.', 'CLE']
# 4
# Julio Jones
# Julio Jones ATL
# ['Julio', 'Jones', 'ATL']
# 3
# JuJu Smith-Schuster
# JuJu Smith-Schuster PIT
# ['JuJu', 'Smith-Schuster', 'PIT']
# 3
# Mike Evans
# Mike Evans TB
# ['Mike', 'Evans', 'TB']
# 3
# Tyler Lockett
# Tyler Lockett SEA
# ['Tyler', 'Lockett', 'SEA']
# 3
# Adam Thielen
# Adam Thielen MIN
# ['Adam', 'Thielen', 'MIN']
# 3
# Keenan Allen
# Keenan Allen LAC
# ['Keenan', 'Allen', 'LAC']
# 3
# Amari Cooper
# Amari Cooper DAL
# ['Amari', 'Cooper', 'DAL']
# 3
# Julian Edelman
# Julian Edelman NE
# ['Julian', 'Edelman', 'NE']
# 3
# Tyler Boyd
# Tyler Boyd CIN
# ['Tyler', 'Boyd', 'CIN']
# 3
# Brandin Cooks
# Brandin Cooks LAR
# ['Brandin', 'Cooks', 'LAR']
# 3
# Stefon Diggs
# Stefon Diggs MIN
# ['Stefon', 'Diggs', 'MIN']
# 3
# Kenny Golladay
# Kenny Golladay DET
# ['Kenny', 'Golladay', 'DET']
# 3
# D.J. Moore
# D.J. Moore CAR
# ['D.J.', 'Moore', 'CAR']
# 3
# Cooper Kupp
# Cooper Kupp LAR
# ['Cooper', 'Kupp', 'LAR']
# 3
# Dede Westbrook
# Dede Westbrook JAC
# ['Dede', 'Westbrook', 'JAC']
# 3
# Robert Woods
# Robert Woods LAR
# ['Robert', 'Woods', 'LAR']
# 3
# Chris Godwin
# Chris Godwin TB
# ['Chris', 'Godwin', 'TB']
# 3
# Mike Williams
# Mike Williams LAC
# ['Mike', 'Williams', 'LAC']
# 3
# Josh Gordon
# Josh Gordon SEA
# ['Josh', 'Gordon', 'SEA']
# 3
# Allen Robinson
# Allen Robinson CHI
# ['Allen', 'Robinson', 'CHI']
# 3
# Alshon Jeffery
# Alshon Jeffery PHI
# ['Alshon', 'Jeffery', 'PHI']
# 3
# Curtis Samuel
# Curtis Samuel CAR
# ['Curtis', 'Samuel', 'CAR']
# 3
# Robby Anderson
# Robby Anderson NYJ
# ['Robby', 'Anderson', 'NYJ']
# 3
# Dante Pettis
# Dante Pettis SF
# ['Dante', 'Pettis', 'SF']
# 3
# T.Y. Hilton
# T.Y. Hilton IND
# ['T.Y.', 'Hilton', 'IND']
# 3
# Courtland Sutton
# Courtland Sutton DEN
# ['Courtland', 'Sutton', 'DEN']
# 3
# Jarvis Landry
# Jarvis Landry CLE
# ['Jarvis', 'Landry', 'CLE']
# 3
# Marvin Jones
# Marvin Jones DET
# ['Marvin', 'Jones', 'DET']
# 3
# Tyrell Williams
# Tyrell Williams OAK
# ['Tyrell', 'Williams', 'OAK']
# 3
# Larry Fitzgerald
# Larry Fitzgerald ARI
# ['Larry', 'Fitzgerald', 'ARI']
# 3
# Will Fuller
# Will Fuller HOU
# ['Will', 'Fuller', 'HOU']
# 3
# Christian Kirk
# Christian Kirk ARI
# ['Christian', 'Kirk', 'ARI']
# 3
# Emmanuel Sanders
# Emmanuel Sanders SF
# ['Emmanuel', 'Sanders', 'SF']
# 3
# Michael Gallup
# Michael Gallup DAL
# ['Michael', 'Gallup', 'DAL']
# 3
# Corey Davis
# Corey Davis TEN
# ['Corey', 'Davis', 'TEN']
# 3
# Calvin Ridley
# Calvin Ridley ATL
# ['Calvin', 'Ridley', 'ATL']
# 3
# Sammy Watkins
# Sammy Watkins KC
# ['Sammy', 'Watkins', 'KC']
# 3
# Marquise Goodwin
# Marquise Goodwin SF
# ['Marquise', 'Goodwin', 'SF']
# 3
# John Brown
# John Brown BUF
# ['John', 'Brown', 'BUF']
# 3
# DeSean Jackson
# DeSean Jackson PHI
# ['DeSean', 'Jackson', 'PHI']
# 3
# Jamison Crowder
# Jamison Crowder NYJ
# ['Jamison', 'Crowder', 'NYJ']
# 3
# Mohamed Sanu
# Mohamed Sanu NE
# ['Mohamed', 'Sanu', 'NE']
# 3
# Geronimo Allison
# Geronimo Allison GB
# ['Geronimo', 'Allison', 'GB']
# 3
# Ted Ginn
# Ted Ginn NO
# ['Ted', 'Ginn', 'NO']
# 3
# Anthony Miller
# Anthony Miller CHI
# ['Anthony', 'Miller', 'CHI']
# 3
# Zay Jones
# Zay Jones OAK
# ['Zay', 'Jones', 'OAK']
# 3
# Marquez Valdes-Scantling
# Marquez Valdes-Scantling GB
# ['Marquez', 'Valdes-Scantling', 'GB']
# 3
# Cole Beasley
# Cole Beasley BUF
# ['Cole', 'Beasley', 'BUF']
# 3
# James Washington
# James Washington PIT
# ['James', 'Washington', 'PIT']
# 3
# Paul Richardson
# Paul Richardson WAS
# ['Paul', 'Richardson', 'WAS']
# 3
# Devante Parker
# Devante Parker MIA
# ['Devante', 'Parker', 'MIA']
# 3
# Danny Amendola
# Danny Amendola DET
# ['Danny', 'Amendola', 'DET']
# 3
# Randall Cobb
# Randall Cobb DAL
# ['Randall', 'Cobb', 'DAL']
# 3
# Hunter Renfrow
# Hunter Renfrow OAK
# ['Hunter', 'Renfrow', 'OAK']
# 3
# Trey Quinn
# Trey Quinn WAS
# ['Trey', 'Quinn', 'WAS']
# 3
# Taylor Gabriel
# Taylor Gabriel CHI
# ['Taylor', 'Gabriel', 'CHI']
# 3
# Keke Coutee
# Keke Coutee HOU
# ['Keke', 'Coutee', 'HOU']
# 3
# Adam Humphries
# Adam Humphries TEN
# ['Adam', 'Humphries', 'TEN']
# 3
# DaeSean Hamilton
# DaeSean Hamilton DEN
# ['DaeSean', 'Hamilton', 'DEN']
# 3
# Willie Snead
# Willie Snead BAL
# ['Willie', 'Snead', 'BAL']
# 3
# Tre'Quan Smith
# Tre'Quan Smith NO
# ["Tre'Quan", 'Smith', 'NO']
# 3
# Deebo Samuel
# Deebo Samuel SF
# ['Deebo', 'Samuel', 'SF']
# 3
# Miles Boykin
# Miles Boykin BAL
# ['Miles', 'Boykin', 'BAL']
# 3
# John Ross
# John Ross CIN
# ['John', 'Ross', 'CIN']
# 3
# Breshad Perriman
# Breshad Perriman TB
# ['Breshad', 'Perriman', 'TB']
# 3
# Devin Funchess
# Devin Funchess IND
# ['Devin', 'Funchess', 'IND']
# 3
# D.K. Metcalf
# D.K. Metcalf SEA
# ['D.K.', 'Metcalf', 'SEA']
# 3
# Jaron Brown
# Jaron Brown SEA
# ['Jaron', 'Brown', 'SEA']
# 3
# Nelson Agholor
# Nelson Agholor PHI
# ['Nelson', 'Agholor', 'PHI']
# 3
# Marquise Brown
# Marquise Brown BAL
# ['Marquise', 'Brown', 'BAL']
# 3
# Robert Foster
# Robert Foster BUF
# ['Robert', 'Foster', 'BUF']
# 3
# D.J. Chark
# D.J. Chark JAC
# ['D.J.', 'Chark', 'JAC']
# 3
# Chris Conley
# Chris Conley JAC
# ['Chris', 'Conley', 'JAC']
# 3
# Kenny Stills
# Kenny Stills HOU
# ['Kenny', 'Stills', 'HOU']
# 3
# Cody Latimer
# Cody Latimer NYG
# ['Cody', 'Latimer', 'NYG']
# 3
# Phillip Dorsett
# Phillip Dorsett NE
# ['Phillip', 'Dorsett', 'NE']
# 3
# Jakeem Grant
# Jakeem Grant MIA
# ['Jakeem', 'Grant', 'MIA']
# 3
# Terry McLaurin
# Terry McLaurin WAS
# ['Terry', 'McLaurin', 'WAS']
# 3
# Travis Benjamin
# Travis Benjamin LAC
# ['Travis', 'Benjamin', 'LAC']
# 3
# Andy Isabella
# Andy Isabella ARI
# ['Andy', 'Isabella', 'ARI']
# 3
# Chad Beebe
# Chad Beebe MIN
# ['Chad', 'Beebe', 'MIN']
# 3
# Damion Willis
# Damion Willis CIN
# ['Damion', 'Willis', 'CIN']
# 3
# Ryan Grant
# Ryan Grant GB
# ['Ryan', 'Grant', 'GB']
# 3
# Chris Hogan
# Chris Hogan CAR
# ['Chris', 'Hogan', 'CAR']
# 3
# Mecole Hardman
# Mecole Hardman KC
# ['Mecole', 'Hardman', 'KC']
# 3
# Tim Patrick
# Tim Patrick DEN
# ['Tim', 'Patrick', 'DEN']
# 3
# Jarius Wright
# Jarius Wright CAR
# ['Jarius', 'Wright', 'CAR']
# 3
# A.J. Brown
# A.J. Brown TEN
# ['A.J.', 'Brown', 'TEN']
# 3
# KeeSean Johnson
# KeeSean Johnson ARI
# ['KeeSean', 'Johnson', 'ARI']
# 3
# Preston Williams
# Preston Williams MIA
# ['Preston', 'Williams', 'MIA']
# 3
# Bennie Fowler
# Bennie Fowler NYG
# ['Bennie', 'Fowler', 'NYG']
# 3
# J.J. Arcega-Whiteside
# J.J. Arcega-Whiteside PHI
# ['J.J.', 'Arcega-Whiteside', 'PHI']
# 3
# Keith Kirkwood
# Keith Kirkwood NO
# ['Keith', 'Kirkwood', 'NO']
# 3
# Jake Kumerow
# Jake Kumerow GB
# ['Jake', 'Kumerow', 'GB']
# 3
# Gary Jennings
# Gary Jennings SEA
# ['Gary', 'Jennings', 'SEA']
# 3
# Alex Erickson
# Alex Erickson CIN
# ['Alex', 'Erickson', 'CIN']
# 3
# Allen Hurns
# Allen Hurns MIA
# ['Allen', 'Hurns', 'MIA']
# 3
# Olabisi Johnson
# Olabisi Johnson MIN
# ['Olabisi', 'Johnson', 'MIN']
# 3
# Demaryius Thomas
# Demaryius Thomas NYJ
# ['Demaryius', 'Thomas', 'NYJ']
# 3
# Parris Campbell
# Parris Campbell IND
# ['Parris', 'Campbell', 'IND']
# 3
# Cordarrelle Patterson
# Cordarrelle Patterson CHI
# ['Cordarrelle', 'Patterson', 'CHI']
# 3
# Josh Reynolds
# Josh Reynolds LAR
# ['Josh', 'Reynolds', 'LAR']
# 3
# Keelan Cole
# Keelan Cole JAC
# ['Keelan', 'Cole', 'JAC']
# 3
# Tajae Sharpe
# Tajae Sharpe TEN
# ['Tajae', 'Sharpe', 'TEN']
# 3
# Kendrick Bourne
# Kendrick Bourne SF
# ['Kendrick', 'Bourne', 'SF']
# 3
# Dontrelle Inman
# Dontrelle Inman LAC
# ['Dontrelle', 'Inman', 'LAC']
# 3
# Demarcus Robinson
# Demarcus Robinson KC
# ['Demarcus', 'Robinson', 'KC']
# 3
# Ryan Switzer
# Ryan Switzer PIT
# ['Ryan', 'Switzer', 'PIT']
# 3
# Justin Watson
# Justin Watson TB
# ['Justin', 'Watson', 'TB']
# 3
# Jakobi Meyers
# Jakobi Meyers NE
# ['Jakobi', 'Meyers', 'NE']
# 3
# Seth Roberts
# Seth Roberts BAL
# ['Seth', 'Roberts', 'BAL']
# 3
# Kelvin Harmon
# Kelvin Harmon WAS
# ['Kelvin', 'Harmon', 'WAS']
# 3
# Chester Rogers
# Chester Rogers IND
# ['Chester', 'Rogers', 'IND']
# 3
# Russell Shepard
# Russell Shepard NYG
# ['Russell', 'Shepard', 'NYG']
# 3
# Justin Hardy
# Justin Hardy ATL
# ['Justin', 'Hardy', 'ATL']
# 3
# Deon Cain
# Deon Cain IND
# ['Deon', 'Cain', 'IND']
# 3
# John Ursua
# John Ursua SEA
# ['John', 'Ursua', 'SEA']
# 3
# Chris Lacy
# Chris Lacy DET
# ['Chris', 'Lacy', 'DET']
# 3
# Chris Moore
# Chris Moore BAL
# ['Chris', 'Moore', 'BAL']
# 3
# Austin Carr
# Austin Carr NO
# ['Austin', 'Carr', 'NO']
# 3
# DeAndre Carter
# DeAndre Carter HOU
# ['DeAndre', 'Carter', 'HOU']
# 3
# Diontae Johnson
# Diontae Johnson PIT
# ['Diontae', 'Johnson', 'PIT']
# 3
# Isaiah McKenzie
# Isaiah McKenzie BUF
# ['Isaiah', 'McKenzie', 'BUF']
# 3
# Cody Core
# Cody Core NYG
# ['Cody', 'Core', 'NYG']
# 3
# Russell Gage
# Russell Gage ATL
# ['Russell', 'Gage', 'ATL']
# 3
# Damion Ratley
# Damion Ratley CLE
# ['Damion', 'Ratley', 'CLE']
# 3
# Dwayne Harris
# Dwayne Harris OAK
# ['Dwayne', 'Harris', 'OAK']
# 3
# Josh Bellamy
# Josh Bellamy NYJ
# ['Josh', 'Bellamy', 'NYJ']
# 3
# Trent Sherfield
# Trent Sherfield ARI
# ['Trent', 'Sherfield', 'ARI']
# 3
# Juwann Winfree
# Juwann Winfree DEN
# ['Juwann', 'Winfree', 'DEN']
# 3
# Mack Hollins
# Mack Hollins PHI
# ['Mack', 'Hollins', 'PHI']
# 3
# Jaleel Scott
# Jaleel Scott BAL
# ['Jaleel', 'Scott', 'BAL']
# 3
# Travis Fulgham
# Travis Fulgham DET
# ['Travis', 'Fulgham', 'DET']
# 3
# Derrick Willies
# Derrick Willies CLE
# ['Derrick', 'Willies', 'CLE']
# 3
# Deonte Harris
# Deonte Harris NO
# ['Deonte', 'Harris', 'NO']
# 3
# Trevor Davis
# Trevor Davis OAK
# ['Trevor', 'Davis', 'OAK']
# 3
# Malik Turner
# Malik Turner SEA
# ['Malik', 'Turner', 'SEA']
# 3
# Quadree Henderson
# Quadree Henderson CAR
# ['Quadree', 'Henderson', 'CAR']
# 3
# Jehu Chesson
# Jehu Chesson WAS
# ['Jehu', 'Chesson', 'WAS']
# 3
# Zach Pascal
# Zach Pascal IND
# ['Zach', 'Pascal', 'IND']
# 3
# Geremy Davis
# Geremy Davis LAC
# ['Geremy', 'Davis', 'LAC']
# 3
# Diontae Spencer
# Diontae Spencer DEN
# ['Diontae', 'Spencer', 'DEN']
# 3
# Damiere Byrd
# Damiere Byrd ARI
# ['Damiere', 'Byrd', 'ARI']
# 3
# Brandon Powell
# Brandon Powell ATL
# ['Brandon', 'Powell', 'ATL']
# 3
# Richie James
# Richie James SF
# ['Richie', 'James', 'SF']
# 3
# Chad Hansen
# Chad Hansen HOU
# ['Chad', 'Hansen', 'HOU']
# 3
# Scott Miller
# Scott Miller TB
# ['Scott', 'Miller', 'TB']
# 3
# Ray-Ray McCloud
# Ray-Ray McCloud BUF
# ['Ray-Ray', 'McCloud', 'BUF']
# 3
# Byron Pringle
# Byron Pringle KC
# ['Byron', 'Pringle', 'KC']
# 3
# Braxton Berrios
# Braxton Berrios NYJ
# ['Braxton', 'Berrios', 'NYJ']
# 3
# Kalif Raymond
# Kalif Raymond TEN
# ['Kalif', 'Raymond', 'TEN']
# 3
# Javon Wims
# Javon Wims CHI
# ['Javon', 'Wims', 'CHI']
# 3
# Isaac Whitney
# Isaac Whitney HOU
# ['Isaac', 'Whitney', 'HOU']
# 3
# Allen Lazard
# Allen Lazard GB
# ['Allen', 'Lazard', 'GB']
# 3
# Isaiah Ford
# Isaiah Ford MIA
# ['Isaiah', 'Ford', 'MIA']
# 3
# Devin Smith
# Devin Smith DAL
# ['Devin', 'Smith', 'DAL']
# 3
# JoJo Natson
# JoJo Natson LAR
# ['JoJo', 'Natson', 'LAR']
# 3
# Pharoh Cooper
# Pharoh Cooper ARI
# ['Pharoh', 'Cooper', 'ARI']
# 3
# Steven Sims
# Steven Sims WAS
# ['Steven', 'Sims', 'WAS']
# 3
# Gehrig Dieter
# Gehrig Dieter KC
# ['Gehrig', 'Dieter', 'KC']
# 3
# Gunner Olszewski
# Gunner Olszewski NE
# ['Gunner', 'Olszewski', 'NE']
# 3
# Robert Davis
# Robert Davis PHI
# ['Robert', 'Davis', 'PHI']
# 3
# Mike Thomas
# Mike Thomas LAR
# ['Mike', 'Thomas', 'LAR']
# 3
# Khadarel Hodge
# Khadarel Hodge CLE
# ['Khadarel', 'Hodge', 'CLE']
# 3
# Deontay Burnett
# Deontay Burnett SF
# ['Deontay', 'Burnett', 'SF']
# 3
# Krishawn Hogan
# Krishawn Hogan NO
# ['Krishawn', 'Hogan', 'NO']
# 3
# Marcus Johnson
# Marcus Johnson IND
# ['Marcus', 'Johnson', 'IND']
# 3
# Matt Slater
# Matt Slater NE
# ['Matt', 'Slater', 'NE']
# 3
# Verran Tucker
# Verran Tucker KC
# ['Verran', 'Tucker', 'KC']
# 3
# Greg Dortch
# Greg Dortch CAR
# ['Greg', 'Dortch', 'CAR']
# 3
# Reggie White
# Reggie White NYG
# ['Reggie', 'White', 'NYG']
# 3
# Brandon Zylstra
# Brandon Zylstra CAR
# ['Brandon', 'Zylstra', 'CAR']
# 3
# Tyler Ervin
# Tyler Ervin JAC
# ['Tyler', 'Ervin', 'JAC']
# 3
# David Sills
# David Sills NYG
# ['David', 'Sills', 'NYG']
# 3
# Mike Davis
# Mike Davis CHI
# ['Mike', 'Davis', 'CHI']
# 3
# Chad Williams
# Chad Williams IND
# ['Chad', 'Williams', 'IND']
# 3
# N'Keal Harry
# N'Keal Harry NE
# ["N'Keal", 'Harry', 'NE']
# 3
# Stephen Carlson
# Stephen Carlson CLE
# ['Stephen', 'Carlson', 'CLE']
# 3
# Laquon Treadwell
# Laquon Treadwell MIN
# ['Laquon', 'Treadwell', 'MIN']
# 3
# Emmanuel Butler
# Emmanuel Butler NO
# ['Emmanuel', 'Butler', 'NO']
# 3
# Keelan Doss
# Keelan Doss OAK
# ['Keelan', 'Doss', 'OAK']
# 3
# Nsimba Webster
# Nsimba Webster LAR
# ['Nsimba', 'Webster', 'LAR']
# 3
# Artavis Scott
# Artavis Scott LAC
# ['Artavis', 'Scott', 'LAC']
# 3
# Cam Sims
# Cam Sims WAS
# ['Cam', 'Sims', 'WAS']
# 3
# Stanley Morgan Jr.
# Stanley Morgan Jr. CIN
# ['Stanley', 'Morgan', 'Jr.', 'CIN']
# 4
# Taywan Taylor
# Taywan Taylor CLE
# ['Taywan', 'Taylor', 'CLE']
# 3
# Codey McElroy
# Codey McElroy TB
# ['Codey', 'McElroy', 'TB']
# 3
# Lil'Jordan Humphrey
# Lil'Jordan Humphrey NO
# ["Lil'Jordan", 'Humphrey', 'NO']
# 3
# Ventell Bryant
# Ventell Bryant DAL
# ['Ventell', 'Bryant', 'DAL']
# 3
# Marcell Ateman
# Marcell Ateman OAK
# ['Marcell', 'Ateman', 'OAK']
# 3
# Olamide Zaccheaus
# Olamide Zaccheaus ATL
# ['Olamide', 'Zaccheaus', 'ATL']
# 3
# https://www.fantasypros.com/nfl/projections/te.php?week=1&scoring=HALF
# Travis Kelce
# Travis Kelce KC
# ['Travis', 'Kelce', 'KC']
# 3
# George Kittle
# George Kittle SF
# ['George', 'Kittle', 'SF']
# 3
# Zach Ertz
# Zach Ertz PHI
# ['Zach', 'Ertz', 'PHI']
# 3
# Evan Engram
# Evan Engram NYG
# ['Evan', 'Engram', 'NYG']
# 3
# O.J. Howard
# O.J. Howard TB
# ['O.J.', 'Howard', 'TB']
# 3
# Vance McDonald
# Vance McDonald PIT
# ['Vance', 'McDonald', 'PIT']
# 3
# Jared Cook
# Jared Cook NO
# ['Jared', 'Cook', 'NO']
# 3
# David Njoku
# David Njoku CLE
# ['David', 'Njoku', 'CLE']
# 3
# Hunter Henry
# Hunter Henry LAC
# ['Hunter', 'Henry', 'LAC']
# 3
# Mark Andrews
# Mark Andrews BAL
# ['Mark', 'Andrews', 'BAL']
# 3
# Darren Waller
# Darren Waller OAK
# ['Darren', 'Waller', 'OAK']
# 3
# Delanie Walker
# Delanie Walker TEN
# ['Delanie', 'Walker', 'TEN']
# 3
# Eric Ebron
# Eric Ebron IND
# ['Eric', 'Ebron', 'IND']
# 3
# Will Dissly
# Will Dissly SEA
# ['Will', 'Dissly', 'SEA']
# 3
# Austin Hooper
# Austin Hooper ATL
# ['Austin', 'Hooper', 'ATL']
# 3
# Jimmy Graham
# Jimmy Graham GB
# ['Jimmy', 'Graham', 'GB']
# 3
# Vernon Davis
# Vernon Davis WAS
# ['Vernon', 'Davis', 'WAS']
# 3
# Kyle Rudolph
# Kyle Rudolph MIN
# ['Kyle', 'Rudolph', 'MIN']
# 3
# Tyler Eifert
# Tyler Eifert CIN
# ['Tyler', 'Eifert', 'CIN']
# 3
# Adam Shaheen
# Adam Shaheen CHI
# ['Adam', 'Shaheen', 'CHI']
# 3
# Greg Olsen
# Greg Olsen CAR
# ['Greg', 'Olsen', 'CAR']
# 3
# Noah Fant
# Noah Fant DEN
# ['Noah', 'Fant', 'DEN']
# 3
# T.J. Hockenson
# T.J. Hockenson DET
# ['T.J.', 'Hockenson', 'DET']
# 3
# Geoff Swaim
# Geoff Swaim JAC
# ['Geoff', 'Swaim', 'JAC']
# 3
# Jack Doyle
# Jack Doyle IND
# ['Jack', 'Doyle', 'IND']
# 3
# Dallas Goedert
# Dallas Goedert PHI
# ['Dallas', 'Goedert', 'PHI']
# 3
# Jason Witten
# Jason Witten DAL
# ['Jason', 'Witten', 'DAL']
# 3
# Mike Gesicki
# Mike Gesicki MIA
# ['Mike', 'Gesicki', 'MIA']
# 3
# Gerald Everett
# Gerald Everett LAR
# ['Gerald', 'Everett', 'LAR']
# 3
# Charles Clay
# Charles Clay ARI
# ['Charles', 'Clay', 'ARI']
# 3
# Cameron Brate
# Cameron Brate TB
# ['Cameron', 'Brate', 'TB']
# 3
# Jeff Heuerman
# Jeff Heuerman DEN
# ['Jeff', 'Heuerman', 'DEN']
# 3
# Dawson Knox
# Dawson Knox BUF
# ['Dawson', 'Knox', 'BUF']
# 3
# Blake Jarwin
# Blake Jarwin DAL
# ['Blake', 'Jarwin', 'DAL']
# 3
# Ryan Griffin
# Ryan Griffin NYJ
# ['Ryan', 'Griffin', 'NYJ']
# 3
# Nick Vannett
# Nick Vannett PIT
# ['Nick', 'Vannett', 'PIT']
# 3
# Foster Moreau
# Foster Moreau OAK
# ['Foster', 'Moreau', 'OAK']
# 3
# Tyler Higbee
# Tyler Higbee LAR
# ['Tyler', 'Higbee', 'LAR']
# 3
# Ryan Izzo
# Ryan Izzo NE
# ['Ryan', 'Izzo', 'NE']
# 3
# Irv Smith Jr.
# Irv Smith Jr. MIN
# ['Irv', 'Smith', 'Jr.', 'MIN']
# 4
# Hayden Hurst
# Hayden Hurst BAL
# ['Hayden', 'Hurst', 'BAL']
# 3
# Ian Thomas
# Ian Thomas CAR
# ['Ian', 'Thomas', 'CAR']
# 3
# Jonnu Smith
# Jonnu Smith TEN
# ['Jonnu', 'Smith', 'TEN']
# 3
# Garrett Celek
# Garrett Celek SF
# ['Garrett', 'Celek', 'SF']
# 3
# Drew Sample
# Drew Sample CIN
# ['Drew', 'Sample', 'CIN']
# 3
# Jesse James
# Jesse James DET
# ['Jesse', 'James', 'DET']
# 3
# Matt LaCosse
# Matt LaCosse NE
# ['Matt', 'LaCosse', 'NE']
# 3
# James O'Shaughnessy
# James O'Shaughnessy JAC
# ['James', "O'Shaughnessy", 'JAC']
# 3
# C.J. Uzomah
# C.J. Uzomah CIN
# ['C.J.', 'Uzomah', 'CIN']
# 3
# Demetrius Harris
# Demetrius Harris CLE
# ['Demetrius', 'Harris', 'CLE']
# 3
# Zach Gentry
# Zach Gentry PIT
# ['Zach', 'Gentry', 'PIT']
# 3
# Jordan Akins
# Jordan Akins HOU
# ['Jordan', 'Akins', 'HOU']
# 3
# Darren Fells
# Darren Fells HOU
# ['Darren', 'Fells', 'HOU']
# 3
# Luke Stocker
# Luke Stocker ATL
# ['Luke', 'Stocker', 'ATL']
# 3
# Jake Butt
# Jake Butt DEN
# ['Jake', 'Butt', 'DEN']
# 3
# Maxx Williams
# Maxx Williams ARI
# ['Maxx', 'Williams', 'ARI']
# 3
# Eric Saubert
# Eric Saubert OAK
# ['Eric', 'Saubert', 'OAK']
# 3
# Rhett Ellison
# Rhett Ellison NYG
# ['Rhett', 'Ellison', 'NYG']
# 3
# Josh Hill
# Josh Hill NO
# ['Josh', 'Hill', 'NO']
# 3
# Lee Smith
# Lee Smith BUF
# ['Lee', 'Smith', 'BUF']
# 3
# Marcedes Lewis
# Marcedes Lewis GB
# ['Marcedes', 'Lewis', 'GB']
# 3
# Mo Alie-Cox
# Mo Alie-Cox IND
# ['Mo', 'Alie-Cox', 'IND']
# 3
# Trevon Wesco
# Trevon Wesco NYJ
# ['Trevon', 'Wesco', 'NYJ']
# 3
# Nick Boyle
# Nick Boyle BAL
# ['Nick', 'Boyle', 'BAL']
# 3
# Robert Tonyan
# Robert Tonyan GB
# ['Robert', 'Tonyan', 'GB']
# 3
# Garrett Griffin
# Garrett Griffin NO
# ['Garrett', 'Griffin', 'NO']
# 3
# Derek Carrier
# Derek Carrier OAK
# ['Derek', 'Carrier', 'OAK']
# 3
# Jeremy Sprinkle
# Jeremy Sprinkle WAS
# ['Jeremy', 'Sprinkle', 'WAS']
# 3
# Virgil Green
# Virgil Green LAC
# ['Virgil', 'Green', 'LAC']
# 3
# Blake Bell
# Blake Bell KC
# ['Blake', 'Bell', 'KC']
# 3
# Tommy Sweeney
# Tommy Sweeney BUF
# ['Tommy', 'Sweeney', 'BUF']
# 3
# Jordan Leggett
# Jordan Leggett TB
# ['Jordan', 'Leggett', 'TB']
# 3
# Ben Braunecker
# Ben Braunecker CHI
# ['Ben', 'Braunecker', 'CHI']
# 3
# Daniel Brown
# Daniel Brown NYJ
# ['Daniel', 'Brown', 'NYJ']
# 3
# Kaden Smith
# Kaden Smith NYG
# ['Kaden', 'Smith', 'NYG']
# 3
# Tanner Hudson
# Tanner Hudson TB
# ['Tanner', 'Hudson', 'TB']
# 3
# Ross Dwelley
# Ross Dwelley SF
# ['Ross', 'Dwelley', 'SF']
# 3
# Clive Walford
# Clive Walford MIA
# ['Clive', 'Walford', 'MIA']
# 3
# Jaeden Graham
# Jaeden Graham ATL
# ['Jaeden', 'Graham', 'ATL']
# 3
# Chris Manhertz
# Chris Manhertz CAR
# ['Chris', 'Manhertz', 'CAR']
# 3
# Seth DeValve
# Seth DeValve JAC
# ['Seth', 'DeValve', 'JAC']
# 3
# Antony Auclair
# Antony Auclair TB
# ['Antony', 'Auclair', 'TB']
# 3
# Levine Toilolo
# Levine Toilolo SF
# ['Levine', 'Toilolo', 'SF']
# 3
# Dalton Schultz
# Dalton Schultz DAL
# ['Dalton', 'Schultz', 'DAL']
# 3
# MyCole Pruitt
# MyCole Pruitt TEN
# ['MyCole', 'Pruitt', 'TEN']
# 3
# Durham Smythe
# Durham Smythe MIA
# ['Durham', 'Smythe', 'MIA']
# 3
# Jerome Cunningham
# Jerome Cunningham WAS
# ['Jerome', 'Cunningham', 'WAS']
# 3
# Tyrone Swoopes
# Tyrone Swoopes SEA
# ['Tyrone', 'Swoopes', 'SEA']
# 3
# Anthony Firkser
# Anthony Firkser TEN
# ['Anthony', 'Firkser', 'TEN']
# 3
# Darrell Daniels
# Darrell Daniels ARI
# ['Darrell', 'Daniels', 'ARI']
# 3
# Jerell Adams
# Jerell Adams HOU
# ['Jerell', 'Adams', 'HOU']
# 3
# Joshua Perkins
# Joshua Perkins PHI
# ['Joshua', 'Perkins', 'PHI']
# 3
# J.P. Holtz
# J.P. Holtz CHI
# ['J.P.', 'Holtz', 'CHI']
# 3
# Cethan Carter
# Cethan Carter CIN
# ['Cethan', 'Carter', 'CIN']
# 3
# Logan Thomas
# Logan Thomas DET
# ['Logan', 'Thomas', 'DET']
# 3
# Sean Culkin
# Sean Culkin LAC
# ['Sean', 'Culkin', 'LAC']
# 3
# Andrew Beck
# Andrew Beck DEN
# ['Andrew', 'Beck', 'DEN']
# 3
# Troy Fumagalli
# Troy Fumagalli DEN
# ['Troy', 'Fumagalli', 'DEN']
# 3
# Jordan Franks
# Jordan Franks CIN
# ['Jordan', 'Franks', 'CIN']
# 3
# Hale Hentges
# Hale Hentges WAS
# ['Hale', 'Hentges', 'WAS']
# 3
# Pharaoh Brown
# Pharaoh Brown CLE
# ['Pharaoh', 'Brown', 'CLE']
# 3
# Brandon Dillon
# Brandon Dillon MIN
# ['Brandon', 'Dillon', 'MIN']
# 3
# https://www.fantasypros.com/nfl/projections/dst.php?week=1&scoring=HALF
# Baltimore Ravens
# New York Jets
# Cleveland Browns
# Dallas Cowboys
# Seattle Seahawks
# New Orleans Saints
# Philadelphia Eagles
# Detroit Lions
# San Francisco 49ers
# Los Angeles Chargers
# Tampa Bay Buccaneers
# Denver Broncos
# Kansas City Chiefs
# Buffalo Bills
# New England Patriots
# Los Angeles Rams
# Green Bay Packers
# Chicago Bears
# Minnesota Vikings
# Arizona Cardinals
# Miami Dolphins
# Atlanta Falcons
# Washington Redskins
# Tennessee Titans
# New York Giants
# Indianapolis Colts
# Carolina Panthers
# Jacksonville Jaguars
# Cincinnati Bengals
# Oakland Raiders
# Houston Texans
# Pittsburgh Steelers
# https://www.fantasypros.com/nfl/projections/k.php?week=1&scoring=HALF
# Greg Zuerlein
# Greg Zuerlein LAR
# ['Greg', 'Zuerlein', 'LAR']
# 3
# Justin Tucker
# Justin Tucker BAL
# ['Justin', 'Tucker', 'BAL']
# 3
# Stephen Gostkowski
# Stephen Gostkowski NE
# ['Stephen', 'Gostkowski', 'NE']
# 3
# Harrison Butker
# Harrison Butker KC
# ['Harrison', 'Butker', 'KC']
# 3
# Michael Badgley
# Michael Badgley LAC
# ['Michael', 'Badgley', 'LAC']
# 3
# Jake Elliott
# Jake Elliott PHI
# ['Jake', 'Elliott', 'PHI']
# 3
# Austin Seibert
# Austin Seibert CLE
# ['Austin', 'Seibert', 'CLE']
# 3
# Brett Maher
# Brett Maher DAL
# ['Brett', 'Maher', 'DAL']
# 3
# Jason Myers
# Jason Myers SEA
# ['Jason', 'Myers', 'SEA']
# 3
# Wil Lutz
# Wil Lutz NO
# ['Wil', 'Lutz', 'NO']
# 3
# Robbie Gould
# Robbie Gould SF
# ['Robbie', 'Gould', 'SF']
# 3
# Matt Gay
# Matt Gay TB
# ['Matt', 'Gay', 'TB']
# 3
# Ty Long
# Ty Long LAC
# ['Ty', 'Long', 'LAC']
# 3
# Ka'imi Fairbairn
# Ka'imi Fairbairn HOU
# ["Ka'imi", 'Fairbairn', 'HOU']
# 3
# Josh Lambo
# Josh Lambo JAC
# ['Josh', 'Lambo', 'JAC']
# 3
# Dan Bailey
# Dan Bailey MIN
# ['Dan', 'Bailey', 'MIN']
# 3
# Mason Crosby
# Mason Crosby GB
# ['Mason', 'Crosby', 'GB']
# 3
# Brandon McManus
# Brandon McManus DEN
# ['Brandon', 'McManus', 'DEN']
# 3
# Matt Prater
# Matt Prater DET
# ['Matt', 'Prater', 'DET']
# 3
# Eddy Pineiro
# Eddy Pineiro CHI
# ['Eddy', 'Pineiro', 'CHI']
# 3
# Stephen Hauschka
# Stephen Hauschka BUF
# ['Stephen', 'Hauschka', 'BUF']
# 3
# Adam Vinatieri
# Adam Vinatieri IND
# ['Adam', 'Vinatieri', 'IND']
# 3
# Ryan Succop
# Ryan Succop TEN
# ['Ryan', 'Succop', 'TEN']
# 3
# Daniel Carlson
# Daniel Carlson OAK
# ['Daniel', 'Carlson', 'OAK']
# 3
# Joey Slye
# Joey Slye CAR
# ['Joey', 'Slye', 'CAR']
# 3
# Chris Boswell
# Chris Boswell PIT
# ['Chris', 'Boswell', 'PIT']
# 3
# Randy Bullock
# Randy Bullock CIN
# ['Randy', 'Bullock', 'CIN']
# 3
# Aldrick Rosas
# Aldrick Rosas NYG
# ['Aldrick', 'Rosas', 'NYG']
# 3
# Jason Sanders
# Jason Sanders MIA
# ['Jason', 'Sanders', 'MIA']
# 3
# Zane Gonzalez
# Zane Gonzalez ARI
# ['Zane', 'Gonzalez', 'ARI']
# 3
# Dustin Hopkins
# Dustin Hopkins WAS
# ['Dustin', 'Hopkins', 'WAS']
# 3

# %%
proj.projections['k']
# Out:
#                          name team week   fg  fga  xpt fantasy_points
# fp-id-16712   Harrison Butker   KC    5  1.9  2.1  3.3            8.9
# fp-id-16026          Wil Lutz   NO    5  2.2  2.4  2.3            8.8
# fp-id-9534       Robbie Gould   SF    5  2.1  2.3  2.2            8.5
# fp-id-15756  Ka'imi Fairbairn  HOU    5  2.0  2.2  2.5            8.4
# fp-id-16540      Jake Elliott  PHI    5  2.0  2.2  2.5            8.4
# fp-id-14003       Jason Myers  SEA    5  1.9  2.2  2.5            8.1
# fp-id-11345     Greg Zuerlein  LAR    5  2.0  2.2  2.2            8.1
# fp-id-11465     Justin Tucker  BAL    5  2.0  2.2  2.1            8.0
# fp-id-12378       Brett Maher  DAL    5  1.8  2.2  2.3            7.9
# fp-id-19028         Joey Slye  CAR    5  1.9  2.2  2.0            7.6
# fp-id-18545          Matt Gay   TB    5  1.8  2.1  2.2            7.5
# fp-id-17693   Michael Badgley  LAC    5  1.7  2.0  2.2            7.4
# fp-id-9433       Mason Crosby   GB    5  1.7  2.0  2.1            7.3
# fp-id-17575      Eddy Pineiro  CHI    5  1.8  2.0  1.9            7.2
# fp-id-10970        Dan Bailey  MIN    5  1.7  2.0  2.0            7.1
# fp-id-16548     Zane Gonzalez  ARI    5  1.7  2.0  1.9            7.1
# fp-id-9004     Adam Vinatieri  IND    5  1.7  2.1  2.1            7.1
# fp-id-18689    Austin Seibert  CLE    5  1.7  2.0  1.8            7.0
# fp-id-13029     Chris Boswell  PIT    5  1.7  1.9  1.9            6.9
# fp-id-16072     Aldrick Rosas  NYG    5  1.7  1.9  1.8            6.9
# fp-id-14327        Josh Lambo  JAC    5  1.6  1.8  1.8            6.8
# fp-id-13274   Brandon McManus  DEN    5  1.7  1.9  1.7            6.7
# fp-id-11339     Randy Bullock  CIN    5  1.5  1.7  2.2            6.7
# fp-id-9581   Stephen Hauschka  BUF    5  1.5  1.8  1.8            6.4
# fp-id-14347           Ty Long  LAC    5  1.3  1.7  2.1            6.0
# fp-id-17420    Daniel Carlson  OAK    5  1.5  1.7  1.4            5.8
# fp-id-16319        Sam Ficken  NYJ    5  1.4  1.7  1.3            5.5
# fp-id-11818    Dustin Hopkins  WAS    5  1.2  1.4  1.2            4.9
