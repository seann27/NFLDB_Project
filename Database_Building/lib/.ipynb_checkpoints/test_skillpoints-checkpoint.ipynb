# %%
# import here
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# connect to database
print("Setting up database connections . . .")
nfldb_engine = create_engine('mysql+pymysql://root:@localhost:3306/main_stats')
main_engine = nfldb_engine.connect()
# Out:
# Setting up database connections . . .

# %%
sql = "select * from nfl_game_summary"
game_summary = pd.read_sql_query(sql, main_engine, index_col='game_id')

# %%
game_summary.head()
# Out:
#              schedule_date  schedule_season schedule_week  \
# game_id
# 2.009091e+09    09/10/2009             2009             1
# 2.009091e+09    09/13/2009             2009             1
# 2.009091e+09    09/13/2009             2009             1
# 2.009091e+09    09/13/2009             2009             1
# 2.009091e+09    09/13/2009             2009             1
#
#                         team_home  score_home  score_away  \
# game_id
# 2.009091e+09  Pittsburgh Steelers          13          10
# 2.009091e+09    Arizona Cardinals          16          20
# 2.009091e+09      Atlanta Falcons          19           7
# 2.009091e+09     Baltimore Ravens          38          24
# 2.009091e+09    Carolina Panthers          10          38
#
#                         team_away team_favorite_id  spread_favorite  \
# game_id
# 2.009091e+09     Tennessee Titans              PIT             -6.5
# 2.009091e+09  San Francisco 49ers              ARI             -4.5
# 2.009091e+09       Miami Dolphins              ATL             -4.0
# 2.009091e+09   Kansas City Chiefs              BAL            -13.0
# 2.009091e+09  Philadelphia Eagles              PHI             -2.5
#
#              over_under_line  ...  away_shortpass_yds  away_shortpass_att  \
# game_id                       ...
# 2.009091e+09              35  ...               152.0                28.0
# 2.009091e+09              45  ...               159.0                24.0
# 2.009091e+09            44.5  ...               139.0                25.0
# 2.009091e+09            36.5  ...               127.0                22.0
# 2.009091e+09            43.5  ...               102.0                26.0
#
#               away_shortpass_completions away_shortpass_tds  \
# game_id
# 2.009091e+09                        19.0                1.0
# 2.009091e+09                        17.0                1.0
# 2.009091e+09                        19.0                1.0
# 2.009091e+09                        15.0                2.0
# 2.009091e+09                        17.0                2.0
#
#               away_deeppass_yds  away_deeppass_att away_deeppass_completions  \
# game_id
# 2.009091e+09               92.0                7.0                       3.0
# 2.009091e+09               50.0                7.0                       1.0
# 2.009091e+09               37.0                4.0                       2.0
# 2.009091e+09               50.0                2.0                       1.0
# 2.009091e+09                0.0                3.0                       0.0
#
#               away_deeppass_tds  away_sacked  away_interceptions
# game_id
# 2.009091e+09                0.0          1.0                 1.0
# 2.009091e+09                0.0          4.0                 0.0
# 2.009091e+09                0.0          4.0                 1.0
# 2.009091e+09                0.0          3.0                 0.0
# 2.009091e+09                0.0          2.0                 1.0
#
# [5 rows x 44 columns]

# %%
# put this list into NFL_RefMaps package
skillpoint_cols = [
    'gameid',
    'team',
    'opponent',
    'rushing_skillpoints',
    'passing_skillpoints',
    'short_pct',
    'deep_pct'
]

def get_team_skillpoints(game,side):
    team_stats = [int(game['game_id'])]
    side_team = "team_"+side
    side_opp = 'team_away'
    if side == 'away':
        side_opp = 'team_home'
    team = game[side_team]
    team_stats.append(team)
    opponent = game[side_opp]
    team_stats.append(opponent)
    rushing_skillpoints = calculate_rushFP(game,side)
    team_stats.append(rushing_skillpoints)
    passing_skillpoints,short_pct,deep_pct = calculate_passFP(game,side)
    team_stats.append(passing_skillpoints)
    team_stats.append(short_pct)
    team_stats.append(deep_pct)
    team_stats = np.asarray(team_stats)
    return team_stats

def calculate_rushFP(game,side):
    met_yds = side+"_rush_yds"
    met_att = side+"_rush_att"
    met_tds = side+"_rush_tds"
    yards = game[met_yds]
    ypa = yards/game[met_att]
    tds = game[met_tds]
    points = (yards/10)+(tds*6)+ypa
    return points

def calculate_passFP(game,side):
    # short pass cols
    met_sp_yds = side+"_shortpass_yds"
    met_sp_att = side+"_shortpass_att"
    met_sp_comp = side+"_shortpass_completions"
    met_sp_tds = side+"_shortpass_tds"

    # short pass fp
    sp_yards = game[met_sp_yds]
    sp_tds = game[met_sp_tds]
    sp_completion_pct = game[met_sp_comp]/game[met_sp_att]
    sp_points = (sp_yards/10)+(sp_tds*6)+(game[met_sp_comp]*sp_completion_pct)

    # deep pass cols
    met_dp_yds = side+"_deeppass_yds"
    met_dp_att = side+"_deeppass_att"
    met_dp_comp = side+"_deeppass_completions"
    met_dp_tds = side+"_deeppass_tds"

    # deep pass fp
    dp_yards = game[met_dp_yds]
    dp_tds = game[met_dp_tds]
    dp_completion_pct = game[met_dp_comp]/game[met_dp_att]
    dp_points = (dp_yards/10)+(dp_tds*6)+(game[met_dp_comp]*dp_completion_pct)

    # calculate percentage short vs deep
    if sp_points == 0 and dp_points == 0:
        short_pct = 0
        deep_pct = 0
    else:
        short_pct = sp_points/(sp_points+dp_points)
        deep_pct = dp_points/(sp_points+dp_points)

    # calculate total pass fp
    met_int = side+"_interceptions"
    met_sack = side+"_sacked"
    return (sp_points+dp_points-(game[met_int]*2)-game[met_sack]),short_pct,deep_pct


class SkillPoints():

    def __init__(self):
        self.skillpoints = pd.DataFrame(columns=skillpoint_cols)

    def build_skillpoints_dataframe(self,game_summary):
        skillpoints_by_team = []
        for index,game in game_summary.iterrows():
            skillpoints_by_team.append(get_team_skillpoints(game,'home'))
            skillpoints_by_team.append(get_team_skillpoints(game,'away'))

        skillpoints_df = np.vstack(skillpoints_by_team)
        self.skillpoints = pd.DataFrame(data=skillpoints_df,columns=skillpoint_cols)
        return self.skillpoints

# %%
game_summary_unindexed = game_summary.copy().reset_index()
# game_summary_unindexed.head()
sp = SkillPoints()
sp_df = sp.build_skillpoints_dataframe(game_summary_unindexed)

# %%
sp_df
# Out:
#             gameid                  team              opponent  \
# 0     2009091000.0   Pittsburgh Steelers      Tennessee Titans
# 1     2009091000.0      Tennessee Titans   Pittsburgh Steelers
# 2     2009091309.0     Arizona Cardinals   San Francisco 49ers
# 3     2009091309.0   San Francisco 49ers     Arizona Cardinals
# 4     2009091300.0       Atlanta Falcons        Miami Dolphins
# 5     2009091300.0        Miami Dolphins       Atlanta Falcons
# 6     2009091301.0      Baltimore Ravens    Kansas City Chiefs
# 7     2009091301.0    Kansas City Chiefs      Baltimore Ravens
# 8     2009091302.0     Carolina Panthers   Philadelphia Eagles
# 9     2009091302.0   Philadelphia Eagles     Carolina Panthers
# 10    2009091303.0    Cincinnati Bengals        Denver Broncos
# 11    2009091303.0        Denver Broncos    Cincinnati Bengals
# 12    2009091304.0      Cleveland Browns     Minnesota Vikings
# 13    2009091304.0     Minnesota Vikings      Cleveland Browns
# 14    2009091312.0     Green Bay Packers         Chicago Bears
# 15    2009091312.0         Chicago Bears     Green Bay Packers
# 16    2009091305.0        Houston Texans         New York Jets
# 17    2009091305.0         New York Jets        Houston Texans
# 18    2009091306.0    Indianapolis Colts  Jacksonville Jaguars
# 19    2009091306.0  Jacksonville Jaguars    Indianapolis Colts
# 20    2009091307.0    New Orleans Saints         Detroit Lions
# 21    2009091307.0         Detroit Lions    New Orleans Saints
# 22    2009091310.0       New York Giants   Washington Redskins
# 23    2009091310.0   Washington Redskins       New York Giants
# 24    2009091311.0      Seattle Seahawks        St. Louis Rams
# 25    2009091311.0        St. Louis Rams      Seattle Seahawks
# 26    2009091308.0  Tampa Bay Buccaneers        Dallas Cowboys
# 27    2009091308.0        Dallas Cowboys  Tampa Bay Buccaneers
# 28    2009091400.0  New England Patriots         Buffalo Bills
# 29    2009091400.0         Buffalo Bills  New England Patriots
# ...            ...                   ...                   ...
# 4968  2018121501.0        Denver Broncos      Cleveland Browns
# 4969  2018121501.0      Cleveland Browns        Denver Broncos
# 4970  2018121500.0         New York Jets        Houston Texans
# 4971  2018121500.0        Houston Texans         New York Jets
# 4972  2018121600.0       Atlanta Falcons     Arizona Cardinals
# 4973  2018121600.0     Arizona Cardinals       Atlanta Falcons
# 4974  2018121601.0      Baltimore Ravens  Tampa Bay Buccaneers
# 4975  2018121601.0  Tampa Bay Buccaneers      Baltimore Ravens
# 4976  2018121602.0         Buffalo Bills         Detroit Lions
# 4977  2018121602.0         Detroit Lions         Buffalo Bills
# 4978  2018121603.0         Chicago Bears     Green Bay Packers
# 4979  2018121603.0     Green Bay Packers         Chicago Bears
# 4980  2018121604.0    Cincinnati Bengals       Oakland Raiders
# 4981  2018121604.0       Oakland Raiders    Cincinnati Bengals
# 4982  2018121605.0    Indianapolis Colts        Dallas Cowboys
# 4983  2018121605.0        Dallas Cowboys    Indianapolis Colts
# 4984  2018121606.0  Jacksonville Jaguars   Washington Redskins
# 4985  2018121606.0   Washington Redskins  Jacksonville Jaguars
# 4986  2018121611.0      Los Angeles Rams   Philadelphia Eagles
# 4987  2018121611.0   Philadelphia Eagles      Los Angeles Rams
# 4988  2018121607.0     Minnesota Vikings        Miami Dolphins
# 4989  2018121607.0        Miami Dolphins     Minnesota Vikings
# 4990  2018121608.0       New York Giants      Tennessee Titans
# 4991  2018121608.0      Tennessee Titans       New York Giants
# 4992  2018121610.0   Pittsburgh Steelers  New England Patriots
# 4993  2018121610.0  New England Patriots   Pittsburgh Steelers
# 4994  2018121609.0   San Francisco 49ers      Seattle Seahawks
# 4995  2018121609.0      Seattle Seahawks   San Francisco 49ers
# 4996  2018121700.0     Carolina Panthers    New Orleans Saints
# 4997  2018121700.0    New Orleans Saints     Carolina Panthers
#
#      rushing_skillpoints passing_skillpoints            short_pct  \
# 0      5.165217391304348    59.9909090909091   0.6455408477069126
# 1                  12.04   41.57857142857142   0.7647812850504727
# 2      6.352941176470589  44.599999999999994   0.8585271317829458
# 3                   8.94   35.08452380952381   0.8684170448661326
# 4                   10.2   47.76666666666667   0.9524447421299397
# 5     13.963636363636363               33.04   0.8796106557377048
# 6      36.62926829268293   61.56363636363636   0.6948746831878344
# 7      4.605882352941176   37.42727272727272   0.8639532268945356
# 8                   17.7  3.6214285714285737    0.736862293824319
# 9                   30.6  29.315384615384616                  1.0
# 10    17.785185185185185    31.9258064516129                  1.0
# 11                 11.25   37.62173913043478  0.47072674729744196
# 12    13.350000000000001   32.61494252873563   0.7206441317278398
# 13     46.87777777777778    22.2280701754386   0.9072240802675585
# 14                  17.7    32.2030303030303   0.6915543651125806
# 15    11.374193548387098   31.97272727272727   0.4026424084903617
# 16     6.723076923076922  22.566666666666663   0.9234629861982435
# 17                  36.5  44.025396825396825   0.4917075281222959
# 18    16.178571428571427   55.05833333333334   0.7222620927228363
# 19     21.62222222222222                18.2   0.7135416666666666
# 20    20.185714285714283   89.75238095238095   0.7932842017853435
# 21    17.189473684210526   26.32758620689655                  1.0
# 22    14.255172413793103   42.39710144927536   0.7386029881241221
# 23    18.547619047619047  36.099999999999994   0.8004866180048662
# 24     27.61176470588235   61.90492610837438   0.8567200101654123
# 25    11.977777777777778  24.635714285714286   0.7539415869733781
# 26    35.012903225806454  50.483333333333334   0.7930009904258831
# 27     22.71666666666667  61.785714285714285  0.30739476678043226
# 28    16.473913043478262   75.56241134751774    0.682205952714109
# 29    13.736842105263158   38.24761904761905   0.8603471596032461
# ...                  ...                 ...                  ...
# 4968  10.884210526315789   42.04883720930232                  1.0
# 4969                18.5    38.4304347826087   0.7289681319807356
# 4970  17.903225806451612   49.69285714285714   0.7532872441371832
# 4971                 7.8    52.7939393939394   0.6654984022265745
# 4972   41.46296296296296   46.63333333333333   0.7121315969842358
# 4973  15.004761904761905  35.112903225806456    0.908919202518363
# 4974   35.82608695652174               26.05   0.8823529411764706
# 4975  18.695238095238096   19.46315789473684   0.4568884723523899
# 4976  21.299999999999997  32.054761904761904  0.32586616725491613
# 4977   20.53846153846154   43.53188405797101    0.598761527449479
# 4978   19.70714285714286   48.88461538461539   0.9438704703161142
# 4979  19.431578947368422            37.33125   0.8917242351614268
# 4980   33.97894736842105  24.166666666666668                  1.0
# 4981               11.05  40.319704433497535   0.8196936923227427
# 4982   35.12777777777778  29.666666666666668   0.7752808988764045
# 4983   16.29090909090909  31.796969696969697   0.9465535699580004
# 4984  23.815384615384616  3.0999999999999996                  1.0
# 4985            14.56875  29.064285714285717   0.8892849186901314
# 4986  24.755555555555553   55.09444444444445   0.9027921406411582
# 4987  32.800000000000004  43.666666666666664   0.6569343065693432
# 4988    46.0421052631579   39.22222222222223   0.6136246786632391
# 4989  29.400000000000002   7.231372549019607   0.7432954820004832
# 4990              7.6375   27.93030303030303   0.5513941290144474
# 4991   38.74285714285715  16.478947368421053   0.8741342968985245
# 4992                23.1  45.186956521739134   0.6659305189841161
# 4993  14.652631578947368   49.01111111111111   0.5793633838923307
# 4994                13.6   44.92207792207792   0.6580758807588076
# 4995  26.700000000000003   50.02738095238095   0.6438497631502144
# 4996  14.060869565217391   28.24285714285714   0.9211514392991239
# 4997  26.933333333333334  31.871428571428567   0.7745917960971725
#
#                  deep_pct
# 0      0.3544591522930873
# 1      0.2352187149495273
# 2     0.14147286821705427
# 3      0.1315829551338674
# 4     0.04755525787006028
# 5     0.12038934426229508
# 6      0.3051253168121656
# 7     0.13604677310546437
# 8     0.26313770617568083
# 9                     0.0
# 10                    0.0
# 11     0.5292732527025581
# 12    0.27935586827216013
# 13    0.09277591973244147
# 14    0.30844563488741944
# 15     0.5973575915096384
# 16    0.07653701380175659
# 17     0.5082924718777041
# 18    0.27773790727716374
# 19    0.28645833333333337
# 20    0.20671579821465647
# 21                    0.0
# 22     0.2613970118758779
# 23    0.19951338199513383
# 24     0.1432799898345878
# 25    0.24605841302662185
# 26    0.20699900957411685
# 27     0.6926052332195677
# 28    0.31779404728589095
# 29    0.13965284039675385
# ...                   ...
# 4968                  0.0
# 4969  0.27103186801926427
# 4970  0.24671275586281685
# 4971   0.3345015977734254
# 4972   0.2878684030157642
# 4973  0.09108079748163693
# 4974   0.1176470588235294
# 4975   0.5431115276476101
# 4976   0.6741338327450839
# 4977   0.4012384725505211
# 4978  0.05612952968388588
# 4979  0.10827576483857326
# 4980                  0.0
# 4981  0.18030630767725736
# 4982   0.2247191011235955
# 4983  0.05344643004199951
# 4984                  0.0
# 4985  0.11071508130986855
# 4986  0.09720785935884177
# 4987  0.34306569343065696
# 4988  0.38637532133676084
# 4989   0.2567045179995168
# 4990   0.4486058709855526
# 4991  0.12586570310147546
# 4992   0.3340694810158838
# 4993  0.42063661610766934
# 4994   0.3419241192411924
# 4995   0.3561502368497856
# 4996   0.0788485607008761
# 4997   0.2254082039028276
#
# [4998 rows x 7 columns]
