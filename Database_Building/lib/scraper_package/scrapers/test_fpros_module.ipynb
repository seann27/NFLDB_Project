# %%
from FProsScraper import LoadProjections,LoadRankings

# %%
week = 1

# %%
proj = LoadProjections(week)
rank = LoadRankings(week)
# Out:
# https://www.fantasypros.com/nfl/projections/qb.php?week=1&scoring=HALF
# https://www.fantasypros.com/nfl/projections/rb.php?week=1&scoring=HALF
# Error detected in  https://www.fantasypros.com/nfl/projections/rb.php?week=1&scoring=HALF  ... skipping row
# https://www.fantasypros.com/nfl/projections/wr.php?week=1&scoring=HALF
# https://www.fantasypros.com/nfl/projections/te.php?week=1&scoring=HALF
# https://www.fantasypros.com/nfl/projections/dst.php?week=1&scoring=HALF
# https://www.fantasypros.com/nfl/projections/k.php?week=1&scoring=HALF
# https://www.fantasypros.com/nfl/rankings/qb.php?week=1
# https://www.fantasypros.com/nfl/rankings/half-point-ppr-rb.php?week=1
# https://www.fantasypros.com/nfl/rankings/half-point-ppr-wr.php?week=1
# https://www.fantasypros.com/nfl/rankings/half-point-ppr-te.php?week=1
# https://www.fantasypros.com/nfl/rankings/half-point-ppr-flex.php?week=1
# https://www.fantasypros.com/nfl/rankings/k.php?week=1
# https://www.fantasypros.com/nfl/rankings/dst.php?week=1
# https://www.fantasypros.com/nfl/rankings/idp.php?week=1
# https://www.fantasypros.com/nfl/rankings/dl.php?week=1
# https://www.fantasypros.com/nfl/rankings/lb.php?week=1
# https://www.fantasypros.com/nfl/rankings/db.php?week=1

# %%
proj.projections['rb']
# Out:
#                pid                 name team week rush_att rush_yds rush_tds  \
# idx
# 01-rb-16393  16393  Christian McCaffrey  CAR    1     14.6     68.3      0.5
# 01-rb-16421  16421         Alvin Kamara   NO    1     12.5     56.5      0.7
# 01-rb-17240  17240       Saquon Barkley  NYG    1     17.0     76.6      0.6
# 01-rb-16374  16374          Dalvin Cook  MIN    1     16.2     78.3      0.6
# 01-rb-17246  17246           Nick Chubb  CLE    1     18.1     90.6      0.7
# ...            ...                  ...  ...  ...      ...      ...      ...
# 01-rb-17145  17145       Patrick Ricard  BAL    1      0.2      0.8      0.0
# 01-rb-15871  15871           Dan Vitale   GB    1      0.2      0.7      0.0
# 01-rb-13333  13333       Senorise Perry  BUF    1      0.1      0.5      0.0
# 01-rb-16746  16746         Justin Davis  ARI    1      0.2      0.6      0.0
# 01-rb-18720  18720       Bruce Anderson  IND    1      2.1      6.2      0.0
#
#              rec rec_yds rec_tds   fl fantasy_points
# idx
# 01-rb-16393  6.4    52.3     0.3  0.2           19.9
# 01-rb-16421  6.0    50.7     0.4  0.2           19.9
# 01-rb-17240  6.2    44.1     0.2  0.2           19.5
# 01-rb-16374  3.9    31.0     0.2  0.2           17.1
# 01-rb-17246  2.1    16.2     0.2  0.2           16.8
# ...          ...     ...     ...  ...            ...
# 01-rb-17145  0.1     0.9     0.0  0.0            0.3
# 01-rb-15871  0.2     0.8     0.0  0.0            0.3
# 01-rb-13333  0.1     0.5     0.0  0.0            0.2
# 01-rb-16746  0.0     0.1     0.0  0.0            0.1
# 01-rb-18720  0.0     2.6     0.0  0.0            0.0
#
# [131 rows x 12 columns]

# %%
rank.rankings['rb']
# Out:
#             rank    pid                 name team    opp week home_away best  \
# idx
# 01-rb-16393    1  16393  Christian McCaffrey  CAR    LAR    1         1    1
# 01-rb-17240    2  17240       Saquon Barkley  NYG    DAL    1         1    1
# 01-rb-16421    3  16421         Alvin Kamara   NO    HOU    1         1    1
# 01-rb-16374    4  16374          Dalvin Cook  MIN    ATL    1         1    1
# 01-rb-17246    5  17246           Nick Chubb  CLE    TEN    1         1    2
# ...          ...    ...                  ...  ...    ...  ...       ...  ...
# 01-rb-16423  132  16423        Samaje Perine  MIA    BAL    1         1   96
# 01-rb-13955  133  13955        Marcus Murphy   FA  [BYE]    1       N/A   87
# 01-rb-15771  134  15771        Andy Janovich  DEN    OAK    1         1   92
# 01-rb-18292  135  18292     Elijah Holyfield  CAR    LAR    1         1   98
# 01-rb-11410  136  11410       Brandon Bolden   NE    PIT    1         1  105
#
#             worst    avg std_dev proj_points
# idx
# 01-rb-16393    11    2.0     1.1        20.7
# 01-rb-17240    14    2.4     1.2        20.6
# 01-rb-16421     6    2.6     1.0        19.7
# 01-rb-16374    21    5.2     2.5        17.8
# 01-rb-17246    20    6.5     2.3        17.7
# ...           ...    ...     ...         ...
# 01-rb-16423   123  109.5     9.6         0.5
# 01-rb-13955   100   93.5     6.5         0.5
# 01-rb-15771   136  109.3    19.1         0.5
# 01-rb-18292   106  102.0     4.0         0.6
# 01-rb-11410   114  109.5     4.5         0.5
#
# [136 rows x 12 columns]
